# %%
import math
import pandas as pd
import tensorflow as tf
# import keras_tuner.tuners as kt
import matplotlib.pyplot as plt
from tensorflow.keras import Model
from tensorflow.keras import Sequential
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from tensorflow.keras.losses import MeanSquaredLogarithmicError
import numpy as np
import pickle
np.random.seed(0)
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import GridSearchCV

from keras.optimizers import Adam, SGD, Adadelta

# https://www.analyticsvidhya.com/blog/2021/06/dimensionality-reduction-using-autoencoders-in-python/#:~:text=AutoEncoder%20is%20an%20unsupervised%20Artificial,representation%20of%20the%20input%20data.
# https://towardsdatascience.com/improve-your-model-performance-with-auto-encoders-d4ee543b4154

# %% [markdown]
# # Sequencing data

# %%
hundred = pd.read_csv('data/cd_df.csv')
hundred = hundred.set_index("Gene_Symbol")
hundred
# Out:
#               1_CD_plain  2_CD_plain  3_CD_plain  4_CD_plain  5_CD_plain  \
# Gene_Symbol
# AADAC          -0.881250     -8.3859   -3.476500     0.47600   -6.860900
# APOA1          -3.046500     -9.3617   -2.636300     0.93493   -6.478400
# APOA4          -0.918130     -7.1696   -2.648600     0.19887   -7.481800
# APOB           -1.312800     -7.4158   -2.541200     1.91080   -7.065600
# APOC3          -1.277500     -8.0880   -2.169100     0.80647   -7.229600
# ...                  ...         ...         ...         ...         ...
# C16orf78        0.000000      0.0000    0.000000     0.00000    0.000000
# C5orf17         0.086807      0.0000    0.000000     0.13729    0.312130
# LOC100132831    0.013324      1.0355   -0.073483     2.06380   -0.073483
# LOC100288778   -1.318000     -1.1931   -0.414730    -1.44110   -1.630300
# LOC100505851   -0.552520     -1.2848   -0.185230     0.48628   -1.284800
#
#               6_CD_deep_ulcer  7_CD_plain  8_CD_plain  9_CD_plain  \
# Gene_Symbol
# AADAC               -3.757300   -4.744800   -0.044202    -2.50650
# APOA1               -5.871500   -9.417700   -0.653090    -4.26860
# APOA4               -3.041400   -7.560500   -0.947140    -1.66230
# APOB                -3.729600   -6.837700    0.335400    -3.11090
# APOC3               -3.867300   -8.254200   -0.466340    -1.60880
# ...                       ...         ...         ...         ...
# C16orf78             0.000000    0.000000    0.000000     0.00000
# C5orf17              0.000000    0.000000    5.470200     0.00000
# LOC100132831        -0.073483    0.284390    1.419200     1.61160
# LOC100288778        -0.551630   -0.521310   -0.411370    -0.10218
# LOC100505851        -1.284800   -0.075626   -1.284800     0.53256
#
#               12_CD_plain  ...  88_control  89_control  90_control  \
# Gene_Symbol                ...
# AADAC            0.006241  ...   -1.031600     1.16230    0.199200
# APOA1           -0.835050  ...   -0.569040     0.74486    0.200140
# APOA4           -0.893450  ...   -0.829470     0.54624    0.532340
# APOB            -0.016976  ...   -0.000025     1.02530    0.417150
# APOC3           -0.302970  ...   -0.581970     0.59072    0.047763
# ...                   ...  ...         ...         ...         ...
# C16orf78         0.000000  ...    0.000000     0.00000    0.000000
# C5orf17          0.000000  ...    1.930300     0.00000    1.135300
# LOC100132831     0.222560  ...    0.856840     1.88610    0.798830
# LOC100288778    -0.631750  ...   -0.143120     0.14414    0.233390
# LOC100505851     0.293860  ...    0.187480     0.28924   -0.049516
#
#               117_control  118_control  121_control  180_control  \
# Gene_Symbol
# AADAC             0.23903     1.361500    -0.934720    -0.248440
# APOA1            -0.15932     1.051600    -1.207500    -1.068500
# APOA4            -0.29898     0.265380    -0.071699    -1.206200
# APOB              0.14618     1.016900     0.075990    -0.442670
# APOC3            -0.39229     0.535160    -0.996560    -1.302900
# ...                   ...          ...          ...          ...
# C16orf78          0.00000     0.000000     0.000000     0.318080
# C5orf17           0.00000     0.000000     2.197200     1.903000
# LOC100132831      1.26050    -0.073483     0.618750    -0.073483
# LOC100288778     -0.21356     0.143300    -0.565400    -0.642310
# LOC100505851      0.51565    -0.779530    -0.138150    -0.081686
#
#               139_CD_deep_ulcer  237_CD_plain  257_CD_deep_ulcer
# Gene_Symbol
# AADAC                 -5.228900     -0.680680          -1.489900
# APOA1                 -7.455900      0.396090          -2.945300
# APOA4                 -6.297200      0.225200          -1.919800
# APOB                  -5.480500     -0.043606          -2.899300
# APOC3                 -7.370300      0.002768          -1.891600
# ...                         ...           ...                ...
# C16orf78               0.000000      0.000000           0.000000
# C5orf17                2.681100      1.128700           2.535500
# LOC100132831           1.625600      0.820750          -0.073483
# LOC100288778          -0.069144      0.394170          -0.379640
# LOC100505851           0.185020     -0.238480          -1.284800
#
# [221 rows x 260 columns]

# %%
hundred = hundred.T
hundred
# Out:
# Gene_Symbol          AADAC    APOA1     APOA4      APOB     APOC3     AQP9  \
# 1_CD_plain        -0.88125 -3.04650 -0.918130 -1.312800 -1.277500  6.32150
# 2_CD_plain        -8.38590 -9.36170 -7.169600 -7.415800 -8.088000  9.67970
# 3_CD_plain        -3.47650 -2.63630 -2.648600 -2.541200 -2.169100  7.92790
# 4_CD_plain         0.47600  0.93493  0.198870  1.910800  0.806470  0.22229
# 5_CD_plain        -6.86090 -6.47840 -7.481800 -7.065600 -7.229600  9.27050
# ...                    ...      ...       ...       ...       ...      ...
# 121_control       -0.93472 -1.20750 -0.071699  0.075990 -0.996560  4.89670
# 180_control       -0.24844 -1.06850 -1.206200 -0.442670 -1.302900  0.72500
# 139_CD_deep_ulcer -5.22890 -7.45590 -6.297200 -5.480500 -7.370300  9.03570
# 237_CD_plain      -0.68068  0.39609  0.225200 -0.043606  0.002768  5.92230
# 257_CD_deep_ulcer -1.48990 -2.94530 -1.919800 -2.899300 -1.891600  7.62510
#
# Gene_Symbol             C6  CEACAM7   CHI3L1    ABCC2  ...  PPP1R17  WNT8A  \
# 1_CD_plain        -3.50560  5.42790  3.30580 -1.70320  ...  0.00000    0.0
# 2_CD_plain        -5.17740 -0.42569  8.04170 -5.07250  ...  2.52400    0.0
# 3_CD_plain        -4.07780  7.18170  5.55740 -4.25090  ...  0.00000    0.0
# 4_CD_plain        -0.52026 -2.39740 -2.62100  0.84513  ...  0.00000    0.0
# 5_CD_plain        -5.17740  0.88511  7.74180 -5.39240  ...  2.31210    0.0
# ...                    ...      ...      ...      ...  ...      ...    ...
# 121_control        1.88000  1.25710 -0.30353  0.07381  ...  0.62185    0.0
# 180_control       -2.27430 -2.21660  1.06760 -0.13725  ...  0.00000    0.0
# 139_CD_deep_ulcer -3.91130  1.55580  7.39930 -4.61280  ...  0.00000    0.0
# 237_CD_plain      -0.31168  2.62370  1.93600 -0.93539  ...  0.00000    0.0
# 257_CD_deep_ulcer -3.30480  3.64970  6.41240 -2.85500  ...  0.00000    0.0
#
# Gene_Symbol            LSM5    PCDHB3   GUSBP11  C16orf78   C5orf17  \
# 1_CD_plain         0.138210  1.122300 -2.895600   0.00000  0.086807
# 2_CD_plain        -0.119280  1.441600 -1.197300   0.00000  0.000000
# 3_CD_plain         0.245650  1.401300 -1.371100   0.00000  0.000000
# 4_CD_plain        -0.188610  1.007100 -2.561600   0.00000  0.137290
# 5_CD_plain         0.152050  0.067572 -2.720100   0.00000  0.312130
# ...                     ...       ...       ...       ...       ...
# 121_control        0.051042 -1.509700  0.012128   0.00000  2.197200
# 180_control        0.237020  0.452510 -0.216670   0.31808  1.903000
# 139_CD_deep_ulcer -0.089609 -0.323570 -0.006459   0.00000  2.681100
# 237_CD_plain      -0.007745 -0.236450  0.013499   0.00000  1.128700
# 257_CD_deep_ulcer  0.190240  0.442970 -0.393080   0.00000  2.535500
#
# Gene_Symbol        LOC100132831  LOC100288778  LOC100505851
# 1_CD_plain             0.013324     -1.318000     -0.552520
# 2_CD_plain             1.035500     -1.193100     -1.284800
# 3_CD_plain            -0.073483     -0.414730     -0.185230
# 4_CD_plain             2.063800     -1.441100      0.486280
# 5_CD_plain            -0.073483     -1.630300     -1.284800
# ...                         ...           ...           ...
# 121_control            0.618750     -0.565400     -0.138150
# 180_control           -0.073483     -0.642310     -0.081686
# 139_CD_deep_ulcer      1.625600     -0.069144      0.185020
# 237_CD_plain           0.820750      0.394170     -0.238480
# 257_CD_deep_ulcer     -0.073483     -0.379640     -1.284800
#
# [260 rows x 221 columns]

# %% [markdown]
# ## Data pre-processing

# %%
shuffled_df = hundred.sample(frac=1)
shuffled_df
# Out:
# Gene_Symbol          AADAC    APOA1    APOA4      APOB    APOC3    AQP9  \
# 55_control        -1.54050  0.33354 -1.22470 -1.234700  0.55181  1.4302
# 168_CD_plain      -0.92136 -2.54660 -2.48800 -2.419100 -2.00960  4.8755
# 72_control        -0.47416 -0.31107 -0.96473 -0.925070  0.89119  3.1870
# 120_control       -1.48090 -1.67250 -2.15810 -0.826770 -1.36390  6.3541
# 258_CD_plain      -1.56310 -1.67960 -1.38710 -0.013321 -1.14760  3.4411
# ...                    ...      ...      ...       ...      ...     ...
# 107_CD_plain      -1.11610 -1.74270 -0.53816 -1.745400 -1.30290  1.3587
# 279_CD_plain      -7.68410 -8.46800 -8.22400 -8.402600 -8.83370  7.2140
# 179_CD_plain      -1.26450 -0.73212 -0.60830 -0.691130 -0.87280  3.0501
# 70_CD_deep_ulcer  -4.27330 -4.14290 -3.11200 -4.005200 -2.91910  4.9455
# 256_CD_deep_ulcer -2.72990 -2.61730 -1.71510 -0.812990 -1.44460  3.9599
#
# Gene_Symbol              C6   CEACAM7  CHI3L1    ABCC2  ...  PPP1R17   WNT8A  \
# 55_control         2.953400   3.16100  0.8389 -1.76750  ...   3.4562  1.7602
# 168_CD_plain      -2.640900   1.40780  2.9396 -3.14160  ...   0.0000  0.0000
# 72_control         0.094616  -0.43266 -1.1968 -1.21560  ...   0.0000  1.1020
# 120_control       -0.465450   1.36980  5.3490 -0.60178  ...   0.0000  0.0000
# 258_CD_plain      -2.164800   1.30790  1.6726 -0.25756  ...   0.0000  0.0000
# ...                     ...       ...     ...      ...  ...      ...     ...
# 107_CD_plain      -3.166600   4.08550  2.9676 -1.82800  ...   0.0000  0.0000
# 279_CD_plain      -5.177400  11.71480  4.5251 -5.26600  ...   0.0000  0.0000
# 179_CD_plain      -1.596200   2.46790  2.9987 -0.73609  ...   0.0000  0.0000
# 70_CD_deep_ulcer  -1.944200   3.96700  4.7686 -3.55790  ...   0.0000  0.0000
# 256_CD_deep_ulcer -5.177400   3.38010  1.6608 -1.31380  ...   0.0000  0.0000
#
# Gene_Symbol            LSM5   PCDHB3  GUSBP11  C16orf78  C5orf17  \
# 55_control         1.465400  0.80413  0.10316    1.7602   3.3452
# 168_CD_plain       1.580900 -0.40516 -1.00640    0.0000   0.0000
# 72_control         1.437600 -0.29774 -0.30720    0.0000   2.1306
# 120_control       -0.108180 -2.65280 -0.21670    0.0000   0.0000
# 258_CD_plain      -0.247330  0.38147  0.22249    0.0000   0.0000
# ...                     ...      ...      ...       ...      ...
# 107_CD_plain       0.572210  0.46897 -1.15240    0.0000   0.0000
# 279_CD_plain       0.756330  1.18660 -1.31800    0.0000   1.6409
# 179_CD_plain      -0.186330  0.04492  0.31595    0.0000   1.1068
# 70_CD_deep_ulcer   0.725210  0.37639 -0.11371    0.0000   1.6773
# 256_CD_deep_ulcer -0.007281 -1.55040  0.12979    0.0000   0.0000
#
# Gene_Symbol        LOC100132831  LOC100288778  LOC100505851
# 55_control            -0.073483      0.872960       2.08140
# 168_CD_plain          -0.073483      0.168800      -0.58654
# 72_control            -0.073483      1.371600      -1.28480
# 120_control           -0.073483     -0.157120      -0.22499
# 258_CD_plain          -0.073483      0.153140      -1.28480
# ...                         ...           ...           ...
# 107_CD_plain           0.937230     -0.419960       0.62623
# 279_CD_plain           0.889330     -0.848910       0.70267
# 179_CD_plain           1.451100      0.007703       0.11081
# 70_CD_deep_ulcer       2.018800      0.670880       0.22030
# 256_CD_deep_ulcer      0.572630     -0.307110      -1.28480
#
# [260 rows x 221 columns]

# %%
split_pt = int(0.7*len(shuffled_df))

x_train = shuffled_df[:split_pt]
x_test = shuffled_df[split_pt:]

# %% [markdown]
# # Feature scaling

# %%
from sklearn.preprocessing import MinMaxScaler

def scale_datasets(x_train, x_test):
  """
  Standard Scale test and train data
  """
  standard_scaler = MinMaxScaler()
  x_train_scaled = pd.DataFrame(
      standard_scaler.fit_transform(x_train),
      index = x_train.index,
      columns=x_train.columns
  )

  x_test_scaled = pd.DataFrame(
      standard_scaler.transform(x_test),
      index = x_test.index,
      columns = x_test.columns
  )
  return x_train_scaled, x_test_scaled
  
x_train_scaled, x_test_scaled = scale_datasets(x_train, x_test)

# %%
x_train_scaled
# Out:
# Gene_Symbol      AADAC     APOA1     APOA4      APOB     APOC3      AQP9  \
# 55_control    0.702813  0.799052  0.719665  0.729547  0.794953  0.256451
# 168_CD_plain  0.751408  0.603707  0.622768  0.627712  0.606860  0.520576
# 72_control    0.786508  0.755331  0.739605  0.756170  0.819875  0.391132
# 120_control   0.707491  0.662993  0.648072  0.764621  0.654276  0.633929
# 258_CD_plain  0.701039  0.662511  0.707208  0.834562  0.670160  0.410612
# ...                ...       ...       ...       ...       ...       ...
# 15_CD_plain   0.382762  0.384030  0.377332  0.360165  0.300915  0.340090
# 182_CD_plain  0.679910  0.584723  0.722426  0.643867  0.740014  0.650358
# 164_CD_plain  0.754656  0.556562  0.694062  0.748334  0.535534  0.133869
# 53_CD_plain   0.591140  0.585802  0.750282  0.753309  0.603372  0.469634
# 97_CD_plain   0.817125  0.782223  0.854442  0.867360  0.793421  0.726438
#
# Gene_Symbol         C6   CEACAM7    CHI3L1     ABCC2  ...   PPP1R17     WNT8A  \
# 55_control    1.000000  0.363133  0.374212  0.611161  ...  0.932722  0.806913
# 168_CD_plain  0.311962  0.251356  0.553554  0.441131  ...  0.000000  0.000000
# 72_control    0.648401  0.134017  0.200420  0.679453  ...  0.000000  0.505180
# 120_control   0.579519  0.248934  0.759250  0.755407  ...  0.000000  0.000000
# 258_CD_plain  0.370517  0.244987  0.445387  0.798000  ...  0.000000  0.000000
# ...                ...       ...       ...       ...  ...       ...       ...
# 15_CD_plain   0.077348  0.890965  0.261140  0.205779  ...  0.000000  0.000000
# 182_CD_plain  0.468650  0.295686  0.649939  0.609862  ...  0.000000  0.000000
# 164_CD_plain  0.319071  0.154562  0.440487  0.824013  ...  0.000000  0.000000
# 53_CD_plain   0.213239  0.348800  0.485094  0.722492  ...  0.000000  0.000000
# 97_CD_plain   0.246396  0.228774  0.611752  0.699944  ...  0.000000  0.000000
#
# Gene_Symbol       LSM5    PCDHB3   GUSBP11  C16orf78   C5orf17  LOC100132831  \
# 55_control    0.653998  0.860533  0.837016       1.0  0.550415      0.000000
# 168_CD_plain  0.692339  0.578107  0.619998       0.0  0.000000      0.000000
# 72_control    0.644769  0.603195  0.756754       0.0  0.350566      0.000000
# 120_control   0.131632  0.053179  0.774455       0.0  0.000000      0.000000
# 258_CD_plain  0.085440  0.761822  0.860355       0.0  0.000000      0.000000
# ...                ...       ...       ...       ...       ...           ...
# 15_CD_plain   0.149005  0.740343  0.641698       0.0  0.000000      0.694951
# 182_CD_plain  0.229358  0.640000  0.731908       0.0  0.422815      0.096205
# 164_CD_plain  0.211405  0.797333  0.896369       0.0  0.234352      0.000000
# 53_CD_plain   0.100262  0.564160  0.879910       0.0  0.477754      0.000000
# 97_CD_plain   0.427867  0.183754  0.000000       0.0  0.000000      0.605142
#
# Gene_Symbol   LOC100288778  LOC100505851
# 55_control        0.778617      0.940755
# 168_CD_plain      0.607899      0.206271
# 72_control        0.899508      0.014040
# 120_control       0.528882      0.305806
# 258_CD_plain      0.604102      0.014040
# ...                    ...           ...
# 15_CD_plain       0.485461      0.300471
# 182_CD_plain      0.502320      0.615334
# 164_CD_plain      0.496177      0.402714
# 53_CD_plain       0.537702      0.304807
# 97_CD_plain       0.000000      0.361919
#
# [182 rows x 221 columns]

# %%
x_train_scaled.isnull().values.any()
# Out:
# False

# %%
x_test_scaled.isnull().values.any()
# Out:
# False

# %%
x_train_scaled.to_csv('data/260_sample_train_scaled.csv', index_label = "Patient_ID")
x_test_scaled.to_csv('data/260_sample_test_scaled.csv', index_label = "Patient_ID")

# %% [markdown]
# # Autoencoder model

# %%
from tensorflow.keras import Input
from tensorflow.keras.layers import Conv1D, Conv2D, LeakyReLU, MaxPool1D, AveragePooling1D, UpSampling1D, Flatten, Dense, Reshape, BatchNormalization
from tensorflow.keras import initializers


class AutoEncoder(Model):

    def __init__(self, n_inputs, init_fn, n_bottleneck=32):

        super().__init__()

        self.encoder = Sequential(
            [

                Input(shape=(n_inputs,)),
                # encoder level 1
                Dense(n_inputs*2, kernel_initializer=init_fn, bias_initializer=initializers.Zeros()),
                BatchNormalization(),
                LeakyReLU(),
                # encoder level 2
                Dense(n_inputs, kernel_initializer=init_fn, bias_initializer=initializers.Zeros()),
                BatchNormalization(),
                LeakyReLU(),
                # bottleneck
                Dense(n_bottleneck, kernel_initializer=init_fn, bias_initializer=initializers.Zeros())
            ]
        )

        self.decoder = Sequential(
            [
                
                # define decoder, level 1
                Dense(n_inputs, kernel_initializer=init_fn, bias_initializer=initializers.Zeros()),
                BatchNormalization(),
                LeakyReLU(),
                # decoder level 2,
                Dense(n_inputs*2, kernel_initializer=init_fn, bias_initializer=initializers.Zeros()),
                BatchNormalization(),
                LeakyReLU(),
                # output layer
                Dense(n_inputs, activation='linear', kernel_initializer=init_fn, bias_initializer=initializers.Zeros())
            ]
        )

    def call(self, inputs):

        encoded = self.encoder(inputs)
        decoded = self.decoder(encoded)
        return decoded

# %% [markdown]
# ## Hyperparameter grid search

# %%
# initialisation functions

        
def get_init(init_fn):
    if init_fn == 'init_xavier_uniform':
        initializer = tf.keras.initializers.GlorotUniform()
    elif init_fn == 'init_xavier_normal':
        initializer = tf.keras.initializers.GlorotNormal()
    elif init_fn == 'zeros':
        initializer = tf.keras.initializers.Zeros()
    elif init_fn == 'ones':
        initializer = tf.keras.initializers.Ones()
    elif init_fn == 'he_uniform':
        initializer = tf.keras.initializers.heUniform()
    elif init_fn == 'he_normal':
        initializer = tf.keras.initializers.heNormal()
        
    return initializer

# %%
x_train_scaled
# Out:
# Gene_Symbol      AADAC     APOA1     APOA4      APOB     APOC3      AQP9  \
# 55_control    0.702813  0.799052  0.719665  0.729547  0.794953  0.256451
# 168_CD_plain  0.751408  0.603707  0.622768  0.627712  0.606860  0.520576
# 72_control    0.786508  0.755331  0.739605  0.756170  0.819875  0.391132
# 120_control   0.707491  0.662993  0.648072  0.764621  0.654276  0.633929
# 258_CD_plain  0.701039  0.662511  0.707208  0.834562  0.670160  0.410612
# ...                ...       ...       ...       ...       ...       ...
# 15_CD_plain   0.382762  0.384030  0.377332  0.360165  0.300915  0.340090
# 182_CD_plain  0.679910  0.584723  0.722426  0.643867  0.740014  0.650358
# 164_CD_plain  0.754656  0.556562  0.694062  0.748334  0.535534  0.133869
# 53_CD_plain   0.591140  0.585802  0.750282  0.753309  0.603372  0.469634
# 97_CD_plain   0.817125  0.782223  0.854442  0.867360  0.793421  0.726438
#
# Gene_Symbol         C6   CEACAM7    CHI3L1     ABCC2  ...   PPP1R17     WNT8A  \
# 55_control    1.000000  0.363133  0.374212  0.611161  ...  0.932722  0.806913
# 168_CD_plain  0.311962  0.251356  0.553554  0.441131  ...  0.000000  0.000000
# 72_control    0.648401  0.134017  0.200420  0.679453  ...  0.000000  0.505180
# 120_control   0.579519  0.248934  0.759250  0.755407  ...  0.000000  0.000000
# 258_CD_plain  0.370517  0.244987  0.445387  0.798000  ...  0.000000  0.000000
# ...                ...       ...       ...       ...  ...       ...       ...
# 15_CD_plain   0.077348  0.890965  0.261140  0.205779  ...  0.000000  0.000000
# 182_CD_plain  0.468650  0.295686  0.649939  0.609862  ...  0.000000  0.000000
# 164_CD_plain  0.319071  0.154562  0.440487  0.824013  ...  0.000000  0.000000
# 53_CD_plain   0.213239  0.348800  0.485094  0.722492  ...  0.000000  0.000000
# 97_CD_plain   0.246396  0.228774  0.611752  0.699944  ...  0.000000  0.000000
#
# Gene_Symbol       LSM5    PCDHB3   GUSBP11  C16orf78   C5orf17  LOC100132831  \
# 55_control    0.653998  0.860533  0.837016       1.0  0.550415      0.000000
# 168_CD_plain  0.692339  0.578107  0.619998       0.0  0.000000      0.000000
# 72_control    0.644769  0.603195  0.756754       0.0  0.350566      0.000000
# 120_control   0.131632  0.053179  0.774455       0.0  0.000000      0.000000
# 258_CD_plain  0.085440  0.761822  0.860355       0.0  0.000000      0.000000
# ...                ...       ...       ...       ...       ...           ...
# 15_CD_plain   0.149005  0.740343  0.641698       0.0  0.000000      0.694951
# 182_CD_plain  0.229358  0.640000  0.731908       0.0  0.422815      0.096205
# 164_CD_plain  0.211405  0.797333  0.896369       0.0  0.234352      0.000000
# 53_CD_plain   0.100262  0.564160  0.879910       0.0  0.477754      0.000000
# 97_CD_plain   0.427867  0.183754  0.000000       0.0  0.000000      0.605142
#
# Gene_Symbol   LOC100288778  LOC100505851
# 55_control        0.778617      0.940755
# 168_CD_plain      0.607899      0.206271
# 72_control        0.899508      0.014040
# 120_control       0.528882      0.305806
# 258_CD_plain      0.604102      0.014040
# ...                    ...           ...
# 15_CD_plain       0.485461      0.300471
# 182_CD_plain      0.502320      0.615334
# 164_CD_plain      0.496177      0.402714
# 53_CD_plain       0.537702      0.304807
# 97_CD_plain       0.000000      0.361919
#
# [182 rows x 221 columns]

# %%
def create_model(optimizer, learn_rate, init):
    n_bottleneck = 32 
    init_fn = get_init(init)
    
    if optimizer=="Adam":
        opt = Adam(learning_rate=learn_rate)
    elif optimizer=="SGD":
        opt = SGD(learning_rate=learn_rate)
    else:
        opt = Adadelta(learning_rate=lrn_rate) 
    auto_encoder = AutoEncoder(len(x_train_scaled.columns), init_fn, n_bottleneck)
    auto_encoder.compile(optimizer=opt, loss='mse', metrics=['mse'])
    return auto_encoder

model = KerasRegressor(build_fn = create_model)
learn_rate = [0.001, 0.01, 0.1, 0.2]
init = ['init_xavier_uniform', 'init_xavier_normal', 'zeros', 'ones', 'he_uniform', 'he_normal']
batch_size = [16, 32, 60, 100, 182]


param_grid = {'optimizer':['SGD', 'Adam'], 'epochs':[150], 'batch_size':batch_size, 'learn_rate':learn_rate, 'init':init}
grid = GridSearchCV(estimator=model, scoring='neg_mean_squared_error', param_grid=param_grid)
result = grid.fit(x_train_scaled, x_train_scaled)
print(result)

# %%
grid.best_params_

# %%
grid.cv_results_["split0_test_score"]

# %% [markdown]
# ## Train model with best hyperparameters

# %%
n_bottleneck = 32
initializer = tf.keras.initializers.GlorotNormal()
auto_encoder = AutoEncoder(len(x_train_scaled.columns),initializer, n_bottleneck)
opt = Adam(learning_rate=0.001)
auto_encoder.compile(optimizer='adam', loss='mse', metrics=['mse'])

# %%
split_pt = int(0.8*len(x_train_scaled))

x_val_scaled = x_train_scaled[split_pt:]
x_train_scaled_part = x_train_scaled[:split_pt]
x_val_scaled
# Out:
# Gene_Symbol           AADAC     APOA1     APOA4      APOB     APOC3      AQP9  \
# 217_CD_deep_ulcer  0.606202  0.552086  0.569016  0.578221  0.538787  0.896575
# 85_control         0.957499  0.847428  0.864091  0.904289  0.814344  0.000000
# 175_CD_plain       0.820595  0.794473  0.873303  0.804521  0.787592  0.406395
# 1_CD_plain         0.754556  0.569802  0.743179  0.722832  0.660621  0.631430
# 156_CD_plain       0.880244  0.831975  0.878531  0.813158  0.793081  0.230754
# 157_CD_plain       0.483086  0.375966  0.502569  0.372005  0.400784  0.720458
# 109_CD_deep_ulcer  0.588990  0.346462  0.321700  0.330742  0.342383  0.855001
# 73_CD_plain        0.780746  0.737652  0.800068  0.844755  0.671768  0.386800
# 71_CD_plain        0.716674  0.624889  0.672977  0.831450  0.695532  0.409623
# 141_CD_plain       0.751728  0.788205  0.819058  0.834981  0.750507  0.519595
# 139_CD_deep_ulcer  0.413318  0.270736  0.330598  0.364490  0.213206  0.839507
# 205_CD_plain       0.689917  0.624292  0.691078  0.772835  0.667024  0.372441
# 32_CD_plain        0.767771  0.820067  0.787365  0.720115  0.770098  0.385374
# 39_control         0.759528  0.654325  0.640256  0.734904  0.573558  0.294414
# 207_CD_plain       0.618972  0.442475  0.537553  0.536847  0.533317  0.565431
# 133_CD_deep_ulcer  0.423231  0.189177  0.201655  0.314122  0.130506  0.869329
# 162_CD_plain       0.665845  0.700547  0.782192  0.830080  0.737408  0.327111
# 195_CD_plain       0.812560  0.801711  0.905105  0.686299  0.842016  0.361456
# 36_control         0.812336  0.874938  0.844565  0.745041  0.854888  0.232486
# 237_CD_plain       0.770299  0.803294  0.830874  0.831959  0.754635  0.600826
# 7_CD_plain         0.451314  0.137677  0.233701  0.247797  0.148299  0.561698
# 108_CD_plain       0.759696  0.842957  0.891460  0.799771  0.857158  0.239762
# 140_CD_plain       0.616602  0.477370  0.579271  0.560182  0.565370  0.673610
# 185_CD_plain       0.666724  0.401725  0.532253  0.568884  0.391480  0.701224
# 86_control         0.884630  0.680125  0.777541  0.862064  0.693909  0.000000
# 117_control        0.842485  0.765624  0.790669  0.848277  0.725625  0.255585
# 26_CD_plain        0.735605  0.720005  0.701333  0.690048  0.625828  0.000000
# 303_CD_plain       0.781692  0.706428  0.762380  0.824484  0.669462  0.414951
# 35_control         0.868755  0.777184  0.832517  0.826357  0.724312  0.000000
# 148_CD_deep_ulcer  0.820946  0.897985  0.934965  0.816291  0.919488  0.465280
# 28_control         0.913545  0.873595  0.907560  0.820765  0.852810  0.229535
# 67_control         0.935844  0.848575  0.854504  0.864477  0.836009  0.381955
# 15_CD_plain        0.382762  0.384030  0.377332  0.360165  0.300915  0.340090
# 182_CD_plain       0.679910  0.584723  0.722426  0.643867  0.740014  0.650358
# 164_CD_plain       0.754656  0.556562  0.694062  0.748334  0.535534  0.133869
# 53_CD_plain        0.591140  0.585802  0.750282  0.753309  0.603372  0.469634
# 97_CD_plain        0.817125  0.782223  0.854442  0.867360  0.793421  0.726438
#
# Gene_Symbol              C6   CEACAM7    CHI3L1     ABCC2  ...   PPP1R17  \
# 217_CD_deep_ulcer  0.123592  0.553864  0.911255  0.429141  ...  0.000000
# 85_control         0.641445  0.212172  0.000000  0.999852  ...  0.000000
# 175_CD_plain       0.418544  0.144439  0.277901  0.738467  ...  0.000000
# 1_CD_plain         0.205613  0.507660  0.584817  0.619118  ...  0.000000
# 156_CD_plain       0.441998  0.064393  0.420774  0.792305  ...  0.000000
# 157_CD_plain       0.030514  0.308137  0.739444  0.252577  ...  0.000000
# 109_CD_deep_ulcer  0.210299  0.626730  0.916369  0.124618  ...  0.191567
# 73_CD_plain        0.842254  0.223941  0.571090  0.844974  ...  0.000000
# 71_CD_plain        0.371587  0.054275  0.508119  0.802600  ...  0.000000
# 141_CD_plain       0.301496  0.354653  0.558335  0.712313  ...  0.000000
# 139_CD_deep_ulcer  0.155717  0.260792  0.934289  0.259086  ...  0.000000
# 205_CD_plain       0.763000  0.086433  0.581420  0.720892  ...  0.000000
# 32_CD_plain        0.372276  0.262310  0.306905  0.617311  ...  0.000000
# 39_control         0.481441  0.122056  0.461617  0.725358  ...  0.000000
# 207_CD_plain       0.000000  0.508540  0.680161  0.448741  ...  0.000000
# 133_CD_deep_ulcer  0.090655  0.540845  0.883842  0.351618  ...  0.000000
# 162_CD_plain       0.782666  0.000000  0.467089  0.920609  ...  0.000000
# 195_CD_plain       0.138978  0.321245  0.478461  0.614304  ...  0.000000
# 36_control         0.605814  0.000000  0.293481  0.624624  ...  0.000000
# 237_CD_plain       0.598431  0.328877  0.467874  0.714126  ...  0.000000
# 7_CD_plain         0.119865  0.405830  0.831919  0.336868  ...  0.000000
# 108_CD_plain       0.328147  0.331000  0.585850  0.806150  ...  0.000000
# 140_CD_plain       0.479104  0.361322  0.820240  0.380486  ...  0.171888
# 185_CD_plain       0.294743  0.505799  0.740255  0.473439  ...  0.000000
# 86_control         0.526825  0.061301  0.250915  0.938453  ...  0.000000
# 117_control        0.677118  0.180838  0.246953  0.911550  ...  0.000000
# 26_CD_plain        0.546467  0.146403  0.398586  0.642084  ...  0.000000
# 303_CD_plain       0.445122  0.325447  0.398014  0.760045  ...  0.000000
# 35_control         0.578185  0.000000  0.391885  0.823626  ...  0.000000
# 148_CD_deep_ulcer  0.455884  0.306422  0.437516  0.705810  ...  0.000000
# 28_control         0.605247  0.100676  0.270851  0.737150  ...  0.000000
# 67_control         0.576439  0.458664  0.377453  0.905464  ...  0.000000
# 15_CD_plain        0.077348  0.890965  0.261140  0.205779  ...  0.000000
# 182_CD_plain       0.468650  0.295686  0.649939  0.609862  ...  0.000000
# 164_CD_plain       0.319071  0.154562  0.440487  0.824013  ...  0.000000
# 53_CD_plain        0.213239  0.348800  0.485094  0.722492  ...  0.000000
# 97_CD_plain        0.246396  0.228774  0.611752  0.699944  ...  0.000000
#
# Gene_Symbol           WNT8A      LSM5    PCDHB3   GUSBP11  C16orf78   C5orf17  \
# 217_CD_deep_ulcer  0.000000  0.299113  0.675162  0.746403       0.0  0.000000
# 85_control         0.000000  0.111343  0.603882  0.858583       0.0  0.261765
# 175_CD_plain       0.000000  0.291561  0.503176  0.791792       0.0  0.000000
# 1_CD_plain         0.000000  0.213424  0.934840  0.250491       0.0  0.014283
# 156_CD_plain       0.000000  0.269097  0.657997  0.737787       0.0  0.262439
# 157_CD_plain       0.000000  0.291574  0.562151  0.851423       0.0  0.000000
# 109_CD_deep_ulcer  0.000000  0.489890  0.848043  0.293657       0.0  0.000000
# 73_CD_plain        0.000000  0.136371  0.429539  0.893253       0.0  0.197479
# 71_CD_plain        0.000000  0.189122  0.512331  0.851884       0.0  0.000000
# 141_CD_plain       0.000000  0.182815  0.463097  0.781689       0.0  0.000000
# 139_CD_deep_ulcer  0.000000  0.137797  0.597162  0.815575       0.0  0.441145
# 205_CD_plain       0.000000  0.270255  0.614627  0.745854       0.0  0.000000
# 32_CD_plain        0.000000  0.529115  0.641441  0.691202       0.0  0.000000
# 39_control         0.000000  0.106951  0.642935  0.884338       0.0  0.000000
# 207_CD_plain       0.000000  0.256300  0.732131  0.814558       0.0  0.928886
# 133_CD_deep_ulcer  0.000000  0.188727  0.711934  0.874625       0.0  0.000000
# 162_CD_plain       0.000000  0.191884  0.710823  0.930237       0.0  0.180499
# 195_CD_plain       0.000000  0.584519  0.648255  0.677814       0.0  0.000000
# 36_control         0.000000  0.686065  0.455577  0.779966       0.0  0.000000
# 237_CD_plain       0.000000  0.164972  0.617509  0.819479       0.0  0.185715
# 7_CD_plain         0.354318  0.203465  0.890948  0.797863       0.0  0.000000
# 108_CD_plain       0.000000  0.363984  0.584747  0.701948       0.0  0.000000
# 140_CD_plain       0.000000  0.331691  0.701299  0.679647       0.0  0.000000
# 185_CD_plain       0.000000  0.150248  0.610468  0.799684       0.0  0.695274
# 86_control         0.000000  0.165149  0.742774  0.898139       0.0  0.322743
# 117_control        0.000000  0.020150  0.694588  0.932774       0.0  0.000000
# 26_CD_plain        0.000000  0.169939  0.770433  0.846472       0.0  0.000000
# 303_CD_plain       0.000000  0.202087  0.811628  0.852702       0.0  0.281740
# 35_control         0.000000  0.279952  0.837386  0.796231       0.0  0.000000
# 148_CD_deep_ulcer  0.000000  0.516201  0.000000  0.856821       0.0  0.000000
# 28_control         0.000000  0.379022  0.548627  0.819818       0.0  0.000000
# 67_control         0.000000  0.175777  0.708120  0.797180       0.0  0.000000
# 15_CD_plain        0.000000  0.149005  0.740343  0.641698       0.0  0.000000
# 182_CD_plain       0.000000  0.229358  0.640000  0.731908       0.0  0.422815
# 164_CD_plain       0.000000  0.211405  0.797333  0.896369       0.0  0.234352
# 53_CD_plain        0.000000  0.100262  0.564160  0.879910       0.0  0.477754
# 97_CD_plain        0.000000  0.427867  0.183754  0.000000       0.0  0.000000
#
# Gene_Symbol        LOC100132831  LOC100288778  LOC100505851
# 217_CD_deep_ulcer      0.487389      0.649495      0.323681
# 85_control             0.429187      0.585560      0.014040
# 175_CD_plain           0.000000      0.783034      0.014040
# 1_CD_plain             0.037036      0.247436      0.215637
# 156_CD_plain           0.318682      0.606022      0.430434
# 157_CD_plain           0.000000      0.407884      0.357648
# 109_CD_deep_ulcer      0.000000      0.277960      0.465092
# 73_CD_plain            0.281440      0.576728      0.448596
# 71_CD_plain            0.612779      0.699692      0.199953
# 141_CD_plain           0.000000      0.538674      0.449466
# 139_CD_deep_ulcer      0.724901      0.550211      0.418682
# 205_CD_plain           0.000000      0.718375      0.171278
# 32_CD_plain            0.011468      1.000000      0.388499
# 39_control             0.437510      0.568302      0.014040
# 207_CD_plain           0.000000      0.568517      0.125094
# 133_CD_deep_ulcer      0.000000      0.503193      0.144990
# 162_CD_plain           0.000000      0.559820      0.652819
# 195_CD_plain           0.055437      0.824642      0.480971
# 36_control             0.000000      0.881882      0.528210
# 237_CD_plain           0.381518      0.662538      0.302092
# 7_CD_plain             0.152684      0.440587      0.346926
# 108_CD_plain           0.285041      0.680789      0.485450
# 140_CD_plain           0.094669      0.594084      0.490213
# 185_CD_plain           0.000000      0.472987      0.687287
# 86_control             0.000000      0.565647      0.392386
# 117_control            0.569134      0.515199      0.509704
# 26_CD_plain            0.458164      0.647281      0.390992
# 303_CD_plain           0.126816      0.389720      0.014040
# 35_control             0.653268      0.610321      0.748211
# 148_CD_deep_ulcer      0.000000      0.780115      0.976489
# 28_control             0.247070      0.698991      0.014040
# 67_control             0.000000      0.541455      0.381378
# 15_CD_plain            0.694951      0.485461      0.300471
# 182_CD_plain           0.096205      0.502320      0.615334
# 164_CD_plain           0.000000      0.496177      0.402714
# 53_CD_plain            0.000000      0.537702      0.304807
# 97_CD_plain            0.605142      0.000000      0.361919
#
# [37 rows x 221 columns]

# %%
x_train_scaled_part
# Out:
# Gene_Symbol           AADAC     APOA1     APOA4      APOB     APOC3      AQP9  \
# 55_control         0.702813  0.799052  0.719665  0.729547  0.794953  0.256451
# 168_CD_plain       0.751408  0.603707  0.622768  0.627712  0.606860  0.520576
# 72_control         0.786508  0.755331  0.739605  0.756170  0.819875  0.391132
# 120_control        0.707491  0.662993  0.648072  0.764621  0.654276  0.633929
# 258_CD_plain       0.701039  0.662511  0.707208  0.834562  0.670160  0.410612
# ...                     ...       ...       ...       ...       ...       ...
# 174_CD_plain       0.507857  0.504568  0.553361  0.622493  0.537040  0.428029
# 274_CD_plain       0.884177  0.785462  0.883061  0.912750  0.767023  0.153630
# 160_CD_plain       0.847110  0.735907  0.829303  0.828346  0.720977  0.539274
# 227_CD_plain       0.690145  0.466851  0.655650  0.637548  0.579492  0.666066
# 150_CD_deep_ulcer  0.623399  0.694009  0.720248  0.641013  0.718839  0.518568
#
# Gene_Symbol              C6   CEACAM7    CHI3L1     ABCC2  ...   PPP1R17  \
# 55_control         1.000000  0.363133  0.374212  0.611161  ...  0.932722
# 168_CD_plain       0.311962  0.251356  0.553554  0.441131  ...  0.000000
# 72_control         0.648401  0.134017  0.200420  0.679453  ...  0.000000
# 120_control        0.579519  0.248934  0.759250  0.755407  ...  0.000000
# 258_CD_plain       0.370517  0.244987  0.445387  0.798000  ...  0.000000
# ...                     ...       ...       ...       ...  ...       ...
# 174_CD_plain       0.000000  0.199162  0.627999  0.538031  ...  0.000000
# 274_CD_plain       0.421927  0.339556  0.067453  0.968904  ...  0.000000
# 160_CD_plain       0.344702  0.211948  0.437431  0.815641  ...  0.000000
# 227_CD_plain       0.156565  0.411542  0.618804  0.546037  ...  0.000000
# 150_CD_deep_ulcer  0.320350  0.446448  0.785664  0.518072  ...  0.000000
#
# Gene_Symbol           WNT8A      LSM5    PCDHB3   GUSBP11  C16orf78   C5orf17  \
# 55_control         0.806913  0.653998  0.860533  0.837016       1.0  0.550415
# 168_CD_plain       0.000000  0.692339  0.578107  0.619998       0.0  0.000000
# 72_control         0.505180  0.644769  0.603195  0.756754       0.0  0.350566
# 120_control        0.000000  0.131632  0.053179  0.774455       0.0  0.000000
# 258_CD_plain       0.000000  0.085440  0.761822  0.860355       0.0  0.000000
# ...                     ...       ...       ...       ...       ...       ...
# 174_CD_plain       0.000000  0.209337  0.606098  0.908746       0.0  0.088667
# 274_CD_plain       0.000000  0.105102  0.519020  0.829230       0.0  0.115760
# 160_CD_plain       0.000000  0.376194  0.213111  0.789006       0.0  0.000000
# 227_CD_plain       0.000000  0.334649  0.593015  0.716302       0.0  0.000000
# 150_CD_deep_ulcer  0.000000  0.519720  0.772647  0.705934       0.0  0.000000
#
# Gene_Symbol        LOC100132831  LOC100288778  LOC100505851
# 55_control             0.000000      0.778617      0.940755
# 168_CD_plain           0.000000      0.607899      0.206271
# 72_control             0.000000      0.899508      0.014040
# 120_control            0.000000      0.528882      0.305806
# 258_CD_plain           0.000000      0.604102      0.014040
# ...                         ...           ...           ...
# 174_CD_plain           0.395328      0.607002      0.339250
# 274_CD_plain           0.113923      0.580694      0.014040
# 160_CD_plain           0.000000      0.530136      0.898249
# 227_CD_plain           0.000000      0.506008      0.673136
# 150_CD_deep_ulcer      0.000000      0.791919      0.499491
#
# [145 rows x 221 columns]

# %%
history = auto_encoder.fit(
    x_train_scaled_part, 
    x_train_scaled_part, 
    epochs=150, 
    batch_size=32, 
    validation_data=(x_val_scaled, x_val_scaled)
)
# Out:
# Epoch 1/150
# 5/5 [==============================] - 1s 44ms/step - loss: 0.7237 - mse: 0.7237 - val_loss: 0.2478 - val_mse: 0.2478
# Epoch 2/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.2005 - mse: 0.2005 - val_loss: 0.1562 - val_mse: 0.1562
# Epoch 3/150
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0989 - mse: 0.0989 - val_loss: 0.1040 - val_mse: 0.1040
# Epoch 4/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0783 - mse: 0.0783 - val_loss: 0.0931 - val_mse: 0.0931
# Epoch 5/150
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0540 - mse: 0.0540 - val_loss: 0.0952 - val_mse: 0.0952
# Epoch 6/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0366 - mse: 0.0366 - val_loss: 0.0966 - val_mse: 0.0966
# Epoch 7/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0345 - mse: 0.0345 - val_loss: 0.0879 - val_mse: 0.0879
# Epoch 8/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0286 - mse: 0.0286 - val_loss: 0.0780 - val_mse: 0.0780
# Epoch 9/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0252 - mse: 0.0252 - val_loss: 0.0680 - val_mse: 0.0680
# Epoch 10/150
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0226 - mse: 0.0226 - val_loss: 0.0629 - val_mse: 0.0629
# Epoch 11/150
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0207 - mse: 0.0207 - val_loss: 0.0618 - val_mse: 0.0618
# Epoch 12/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0205 - mse: 0.0205 - val_loss: 0.0601 - val_mse: 0.0601
# Epoch 13/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0188 - mse: 0.0188 - val_loss: 0.0582 - val_mse: 0.0582
# Epoch 14/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0190 - mse: 0.0190 - val_loss: 0.0544 - val_mse: 0.0544
# Epoch 15/150
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0185 - mse: 0.0185 - val_loss: 0.0542 - val_mse: 0.0542
# Epoch 16/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0204 - mse: 0.0204 - val_loss: 0.0534 - val_mse: 0.0534
# Epoch 17/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0184 - mse: 0.0184 - val_loss: 0.0501 - val_mse: 0.0501
# Epoch 18/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0173 - mse: 0.0173 - val_loss: 0.0460 - val_mse: 0.0460
# Epoch 19/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0446 - val_mse: 0.0446
# Epoch 20/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0163 - mse: 0.0163 - val_loss: 0.0445 - val_mse: 0.0445
# Epoch 21/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0169 - mse: 0.0169 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 22/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0172 - mse: 0.0172 - val_loss: 0.0423 - val_mse: 0.0423
# Epoch 23/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0176 - mse: 0.0176 - val_loss: 0.0385 - val_mse: 0.0385
# Epoch 24/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.0381 - val_mse: 0.0381
# Epoch 25/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0175 - mse: 0.0175 - val_loss: 0.0381 - val_mse: 0.0381
# Epoch 26/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0149 - mse: 0.0149 - val_loss: 0.0371 - val_mse: 0.0371
# Epoch 27/150
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0170 - mse: 0.0170 - val_loss: 0.0352 - val_mse: 0.0352
# Epoch 28/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0166 - mse: 0.0166 - val_loss: 0.0334 - val_mse: 0.0334
# Epoch 29/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0173 - mse: 0.0173 - val_loss: 0.0323 - val_mse: 0.0323
# Epoch 30/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0148 - mse: 0.0148 - val_loss: 0.0308 - val_mse: 0.0308
# Epoch 31/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0166 - mse: 0.0166 - val_loss: 0.0308 - val_mse: 0.0308
# Epoch 32/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0169 - mse: 0.0169 - val_loss: 0.0290 - val_mse: 0.0290
# Epoch 33/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0177 - mse: 0.0177 - val_loss: 0.0299 - val_mse: 0.0299
# Epoch 34/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0146 - mse: 0.0146 - val_loss: 0.0267 - val_mse: 0.0267
# Epoch 35/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0148 - mse: 0.0148 - val_loss: 0.0268 - val_mse: 0.0268
# Epoch 36/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0175 - mse: 0.0175 - val_loss: 0.0296 - val_mse: 0.0296
# Epoch 37/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0146 - mse: 0.0146 - val_loss: 0.0273 - val_mse: 0.0273
# Epoch 38/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0166 - mse: 0.0166 - val_loss: 0.0252 - val_mse: 0.0252
# Epoch 39/150
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0141 - mse: 0.0141 - val_loss: 0.0236 - val_mse: 0.0236
# Epoch 40/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.0241 - val_mse: 0.0241
# Epoch 41/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0140 - mse: 0.0140 - val_loss: 0.0273 - val_mse: 0.0273
# Epoch 42/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0147 - mse: 0.0147 - val_loss: 0.0234 - val_mse: 0.0234
# Epoch 43/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0233 - val_mse: 0.0233
# Epoch 44/150
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0150 - mse: 0.0150 - val_loss: 0.0228 - val_mse: 0.0228
# Epoch 45/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0140 - mse: 0.0140 - val_loss: 0.0221 - val_mse: 0.0221
# Epoch 46/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0144 - mse: 0.0144 - val_loss: 0.0212 - val_mse: 0.0212
# Epoch 47/150
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0127 - mse: 0.0127 - val_loss: 0.0205 - val_mse: 0.0205
# Epoch 48/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0210 - val_mse: 0.0210
# Epoch 49/150
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0161 - mse: 0.0161 - val_loss: 0.0207 - val_mse: 0.0207
# Epoch 50/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0207 - val_mse: 0.0207
# Epoch 51/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0166 - mse: 0.0166 - val_loss: 0.0195 - val_mse: 0.0195
# Epoch 52/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0178 - val_mse: 0.0178
# Epoch 53/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0186 - val_mse: 0.0186
# Epoch 54/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0142 - mse: 0.0142 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 55/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0145 - mse: 0.0145 - val_loss: 0.0183 - val_mse: 0.0183
# Epoch 56/150
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0173 - val_mse: 0.0173
# Epoch 57/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0174 - val_mse: 0.0174
# Epoch 58/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0183 - val_mse: 0.0183
# Epoch 59/150
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.0174 - val_mse: 0.0174
# Epoch 60/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0166 - val_mse: 0.0166
# Epoch 61/150
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0169 - val_mse: 0.0169
# Epoch 62/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0164 - val_mse: 0.0164
# Epoch 63/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0165 - val_mse: 0.0165
# Epoch 64/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0148 - mse: 0.0148 - val_loss: 0.0179 - val_mse: 0.0179
# Epoch 65/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0157 - val_mse: 0.0157
# Epoch 66/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0162 - val_mse: 0.0162
# Epoch 67/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0138 - mse: 0.0138 - val_loss: 0.0165 - val_mse: 0.0165
# Epoch 68/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0160 - val_mse: 0.0160
# Epoch 69/150
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0152 - val_mse: 0.0152
# Epoch 70/150
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0139 - mse: 0.0139 - val_loss: 0.0163 - val_mse: 0.0163
# Epoch 71/150
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 72/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0152 - val_mse: 0.0152
# Epoch 73/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0161 - val_mse: 0.0161
# Epoch 74/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 75/150
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 76/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0139 - val_mse: 0.0139
# Epoch 77/150
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0124 - mse: 0.0124 - val_loss: 0.0145 - val_mse: 0.0145
# Epoch 78/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0102 - mse: 0.0102 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 79/150
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0140 - val_mse: 0.0140
# Epoch 80/150
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0139 - val_mse: 0.0139
# Epoch 81/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0148 - val_mse: 0.0148
# Epoch 82/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0133 - val_mse: 0.0133
# Epoch 83/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0152 - val_mse: 0.0152
# Epoch 84/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0134 - val_mse: 0.0134
# Epoch 85/150
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0139 - val_mse: 0.0139
# Epoch 86/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 87/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0148 - mse: 0.0148 - val_loss: 0.0152 - val_mse: 0.0152
# Epoch 88/150
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 89/150
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0136 - val_mse: 0.0136
# Epoch 90/150
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0146 - val_mse: 0.0146
# Epoch 91/150
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0148 - val_mse: 0.0148
# Epoch 92/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0102 - mse: 0.0102 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 93/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0136 - val_mse: 0.0136
# Epoch 94/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0129 - val_mse: 0.0129
# Epoch 95/150
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0133 - val_mse: 0.0133
# Epoch 96/150
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0134 - val_mse: 0.0134
# Epoch 97/150
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 98/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0143 - val_mse: 0.0143
# Epoch 99/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0138 - mse: 0.0138 - val_loss: 0.0154 - val_mse: 0.0154
# Epoch 100/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0154 - val_mse: 0.0154
# Epoch 101/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0130 - mse: 0.0130 - val_loss: 0.0130 - val_mse: 0.0130
# Epoch 102/150
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0133 - val_mse: 0.0133
# Epoch 103/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0136 - val_mse: 0.0136
# Epoch 104/150
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 105/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0097 - mse: 0.0097 - val_loss: 0.0129 - val_mse: 0.0129
# Epoch 106/150
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0130 - val_mse: 0.0130
# Epoch 107/150
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0148 - mse: 0.0148 - val_loss: 0.0148 - val_mse: 0.0148
# Epoch 108/150
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0133 - val_mse: 0.0133
# Epoch 109/150
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0134 - val_mse: 0.0134
# Epoch 110/150
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0129 - val_mse: 0.0129
# Epoch 111/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0128 - val_mse: 0.0128
# Epoch 112/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0126 - val_mse: 0.0126
# Epoch 113/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 114/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0118 - val_mse: 0.0118
# Epoch 115/150
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0130 - val_mse: 0.0130
# Epoch 116/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 117/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0127 - val_mse: 0.0127
# Epoch 118/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0124 - val_mse: 0.0124
# Epoch 119/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0123 - val_mse: 0.0123
# Epoch 120/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 121/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0125 - val_mse: 0.0125
# Epoch 122/150
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0118 - val_mse: 0.0118
# Epoch 123/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 124/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 125/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 126/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 127/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 128/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0120 - val_mse: 0.0120
# Epoch 129/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 130/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0101 - mse: 0.0101 - val_loss: 0.0125 - val_mse: 0.0125
# Epoch 131/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0126 - val_mse: 0.0126
# Epoch 132/150
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0121 - val_mse: 0.0121
# Epoch 133/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 134/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0120 - val_mse: 0.0120
# Epoch 135/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0118 - val_mse: 0.0118
# Epoch 136/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 137/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 138/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 139/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0122 - val_mse: 0.0122
# Epoch 140/150
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 141/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 142/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 143/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0121 - val_mse: 0.0121
# Epoch 144/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 145/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0130 - val_mse: 0.0130
# Epoch 146/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0120 - val_mse: 0.0120
# Epoch 147/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 148/150
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0126 - val_mse: 0.0126
# Epoch 149/150
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0123 - val_mse: 0.0123
# Epoch 150/150
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0097 - mse: 0.0097 - val_loss: 0.0129 - val_mse: 0.0129

# %%
auto_encoder.encoder.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 442)               98124
#
#  batch_normalization (BatchN  (None, 442)              1768
#  ormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 442)               0
#
#  dense_1 (Dense)             (None, 221)               97903
#
#  batch_normalization_1 (Batc  (None, 221)              884
#  hNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 221)               0
#
#  dense_2 (Dense)             (None, 32)                7104
#
# =================================================================
# Total params: 205,783
# Trainable params: 204,457
# Non-trainable params: 1,326
# _________________________________________________________________

# %%
auto_encoder.decoder.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 221)               7293
#
#  batch_normalization_2 (Batc  (None, 221)              884
#  hNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 221)               0
#
#  dense_4 (Dense)             (None, 442)               98124
#
#  batch_normalization_3 (Batc  (None, 442)              1768
#  hNormalization)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 442)               0
#
#  dense_5 (Dense)             (None, 221)               97903
#
# =================================================================
# Total params: 205,972
# Trainable params: 204,646
# Non-trainable params: 1,326
# _________________________________________________________________

# %%
# list all data in history
print(history.history.keys())
# Out:
# dict_keys(['loss', 'mse', 'val_loss', 'val_mse'])

# %%
# summarize history for loss
plt.figure()
plt.grid()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss (MSE)')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.tight_layout()
plt.savefig('autoencoder_learning_curve_loss.png', dpi=300)
plt.show()

# %%
from sklearn.metrics import mean_squared_error

# %%
preds = auto_encoder(x_test_scaled.values)
preds = np.asarray(preds)

# %%
true_set = x_test_scaled.values

# %%
mean_squared_error(true_set, preds)
# Out:
# 0.014339100323171598

# %%
auto_encoder.encoder.save_weights("data/models/cd_encoder_221")
