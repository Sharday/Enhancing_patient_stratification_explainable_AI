# %%
import math
import pandas as pd
import tensorflow as tf
# import keras_tuner.tuners as kt
import matplotlib.pyplot as plt
from tensorflow.keras import Model
from tensorflow.keras import Sequential
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from tensorflow.keras.losses import MeanSquaredLogarithmicError
import numpy as np
import pickle
np.random.seed(0)
# from sklearn.datasets import fetch_california_housing

# https://www.analyticsvidhya.com/blog/2021/06/dimensionality-reduction-using-autoencoders-in-python/#:~:text=AutoEncoder%20is%20an%20unsupervised%20Artificial,representation%20of%20the%20input%20data.

# %% [markdown]
# # Sequencing data

# %%
# hundred = pd.read_csv('hundred_patients.csv')
hundred = pd.read_csv('hundred_patients_cd.csv')
hundred = hundred.set_index("Gene_Symbol")
hundred
# Out:
#               1_CD_plain  2_CD_plain  3_CD_plain  4_CD_plain  5_CD_plain  \
# Gene_Symbol
# AADAC          -0.881250    -8.38590    -3.47650     0.47600    -6.86090
# APOA1          -3.046500    -9.36170    -2.63630     0.93493    -6.47840
# APOA4          -0.918130    -7.16960    -2.64860     0.19887    -7.48180
# APOB           -1.312800    -7.41580    -2.54120     1.91080    -7.06560
# APOC3          -1.277500    -8.08800    -2.16910     0.80647    -7.22960
# ...                  ...         ...         ...         ...         ...
# RSL24D1P1       0.000000     0.00000     0.00000     0.00000     0.00000
# MIEN1           0.048895    -0.13047     0.16749    -0.26901    -0.43410
# PCBP1_AS1      -1.101700     0.12465    -0.81007    -0.47922    -0.86561
# LOC100133165    0.000000     0.00000     0.00000     0.00000     0.00000
# DNAJB8          0.000000     0.00000     0.00000     0.00000     0.00000
#
#               6_CD_deep_ulcer  7_CD_plain  8_CD_plain  9_CD_plain  \
# Gene_Symbol
# AADAC               -3.757300   -4.744800   -0.044202   -2.506500
# APOA1               -5.871500   -9.417700   -0.653090   -4.268600
# APOA4               -3.041400   -7.560500   -0.947140   -1.662300
# APOB                -3.729600   -6.837700    0.335400   -3.110900
# APOC3               -3.867300   -8.254200   -0.466340   -1.608800
# ...                       ...         ...         ...         ...
# RSL24D1P1            0.000000    0.000000    0.000000    0.000000
# MIEN1               -0.001796   -0.642020    0.007044    0.002349
# PCBP1_AS1            0.011933   -0.019921    0.073880   -0.322260
# LOC100133165         0.000000    0.000000    0.000000    0.000000
# DNAJB8               0.000000    0.000000    0.000000    0.000000
#
#               12_CD_plain  ...  88_control  89_control  90_control  \
# Gene_Symbol                ...
# AADAC            0.006241  ...   -1.031600    1.162300    0.199200
# APOA1           -0.835050  ...   -0.569040    0.744860    0.200140
# APOA4           -0.893450  ...   -0.829470    0.546240    0.532340
# APOB            -0.016976  ...   -0.000025    1.025300    0.417150
# APOC3           -0.302970  ...   -0.581970    0.590720    0.047763
# ...                   ...  ...         ...         ...         ...
# RSL24D1P1        0.000000  ...    0.000000    0.000000    0.000000
# MIEN1           -0.356140  ...    0.008968    0.265660   -0.075956
# PCBP1_AS1       -0.400690  ...   -0.142800   -0.010798   -0.173880
# LOC100133165     0.000000  ...    0.000000    0.000000    0.000000
# DNAJB8           0.000000  ...    0.000000    0.000000    0.000000
#
#               117_control  118_control  121_control  180_control  \
# Gene_Symbol
# AADAC             0.23903      1.36150    -0.934720    -0.248440
# APOA1            -0.15932      1.05160    -1.207500    -1.068500
# APOA4            -0.29898      0.26538    -0.071699    -1.206200
# APOB              0.14618      1.01690     0.075990    -0.442670
# APOC3            -0.39229      0.53516    -0.996560    -1.302900
# ...                   ...          ...          ...          ...
# RSL24D1P1         0.00000      0.00000     0.000000     0.000000
# MIEN1             0.00660      0.42261    -0.100730    -0.365170
# PCBP1_AS1         0.38871      0.24453     0.044674     0.055407
# LOC100133165      0.00000      0.00000     0.000000     0.000000
# DNAJB8            0.00000      0.00000     0.000000     0.000000
#
#               139_CD_deep_ulcer  237_CD_plain  257_CD_deep_ulcer
# Gene_Symbol
# AADAC                  -5.22890     -0.680680           -1.48990
# APOA1                  -7.45590      0.396090           -2.94530
# APOA4                  -6.29720      0.225200           -1.91980
# APOB                   -5.48050     -0.043606           -2.89930
# APOC3                  -7.37030      0.002768           -1.89160
# ...                         ...           ...                ...
# RSL24D1P1               0.00000      0.000000            0.00000
# MIEN1                  -0.33844      0.009232           -0.10076
# PCBP1_AS1              -0.23596     -0.090641           -0.53052
# LOC100133165            0.00000      0.000000            0.00000
# DNAJB8                  0.00000      0.000000            0.00000
#
# [219 rows x 260 columns]

# %%
hundred = hundred.T
hundred
# Out:
# Gene_Symbol          AADAC    APOA1     APOA4      APOB     APOC3     AQP9  \
# 1_CD_plain        -0.88125 -3.04650 -0.918130 -1.312800 -1.277500  6.32150
# 2_CD_plain        -8.38590 -9.36170 -7.169600 -7.415800 -8.088000  9.67970
# 3_CD_plain        -3.47650 -2.63630 -2.648600 -2.541200 -2.169100  7.92790
# 4_CD_plain         0.47600  0.93493  0.198870  1.910800  0.806470  0.22229
# 5_CD_plain        -6.86090 -6.47840 -7.481800 -7.065600 -7.229600  9.27050
# ...                    ...      ...       ...       ...       ...      ...
# 121_control       -0.93472 -1.20750 -0.071699  0.075990 -0.996560  4.89670
# 180_control       -0.24844 -1.06850 -1.206200 -0.442670 -1.302900  0.72500
# 139_CD_deep_ulcer -5.22890 -7.45590 -6.297200 -5.480500 -7.370300  9.03570
# 237_CD_plain      -0.68068  0.39609  0.225200 -0.043606  0.002768  5.92230
# 257_CD_deep_ulcer -1.48990 -2.94530 -1.919800 -2.899300 -1.891600  7.62510
#
# Gene_Symbol             C6  CEACAM7   CHI3L1    ABCC2  ...     TAF15  \
# 1_CD_plain        -3.50560  5.42790  3.30580 -1.70320  ... -0.438630
# 2_CD_plain        -5.17740 -0.42569  8.04170 -5.07250  ... -0.186170
# 3_CD_plain        -4.07780  7.18170  5.55740 -4.25090  ... -0.022450
# 4_CD_plain        -0.52026 -2.39740 -2.62100  0.84513  ... -0.051751
# 5_CD_plain        -5.17740  0.88511  7.74180 -5.39240  ... -0.065246
# ...                    ...      ...      ...      ...  ...       ...
# 121_control        1.88000  1.25710 -0.30353  0.07381  ... -0.091578
# 180_control       -2.27430 -2.21660  1.06760 -0.13725  ... -0.449260
# 139_CD_deep_ulcer -3.91130  1.55580  7.39930 -4.61280  ... -0.004676
# 237_CD_plain      -0.31168  2.62370  1.93600 -0.93539  ... -0.215020
# 257_CD_deep_ulcer -3.30480  3.64970  6.41240 -2.85500  ... -0.109670
#
# Gene_Symbol         ZFYVE20  LOC100420253    LY6G5B  C5orf58  RSL24D1P1  \
# 1_CD_plain        -0.217540           0.0 -1.977100 -2.04000        0.0
# 2_CD_plain         0.217320           0.0 -1.064900  1.17820        0.0
# 3_CD_plain        -0.222590           0.0 -1.225800 -0.14073        0.0
# 4_CD_plain         0.161830           0.0 -2.689700 -0.18297        0.0
# 5_CD_plain         0.150550           0.0 -1.764500  1.68320        0.0
# ...                     ...           ...       ...      ...        ...
# 121_control        0.014286           0.0  0.066820  0.40598        0.0
# 180_control        0.115300           0.0 -0.306900  1.71240        0.0
# 139_CD_deep_ulcer -0.235810           0.0 -0.071991  1.92100        0.0
# 237_CD_plain      -0.057831           0.0  0.414740  1.05140        0.0
# 257_CD_deep_ulcer -0.452190           0.0 -1.595800  0.70505        0.0
#
# Gene_Symbol           MIEN1  PCBP1_AS1  LOC100133165  DNAJB8
# 1_CD_plain         0.048895  -1.101700           0.0     0.0
# 2_CD_plain        -0.130470   0.124650           0.0     0.0
# 3_CD_plain         0.167490  -0.810070           0.0     0.0
# 4_CD_plain        -0.269010  -0.479220           0.0     0.0
# 5_CD_plain        -0.434100  -0.865610           0.0     0.0
# ...                     ...        ...           ...     ...
# 121_control       -0.100730   0.044674           0.0     0.0
# 180_control       -0.365170   0.055407           0.0     0.0
# 139_CD_deep_ulcer -0.338440  -0.235960           0.0     0.0
# 237_CD_plain       0.009232  -0.090641           0.0     0.0
# 257_CD_deep_ulcer -0.100760  -0.530520           0.0     0.0
#
# [260 rows x 219 columns]

# %% [markdown]
# ## Data pre-processing

# %%
shuffled_df = hundred.sample(frac=1)
# shuffled_df.drop(columns=shuffled_df.columns[-1], 
#         axis=1, 
#         inplace=True)
shuffled_df
# Out:
# Gene_Symbol          AADAC    APOA1    APOA4      APOB    APOC3    AQP9  \
# 55_control        -1.54050  0.33354 -1.22470 -1.234700  0.55181  1.4302
# 168_CD_plain      -0.92136 -2.54660 -2.48800 -2.419100 -2.00960  4.8755
# 72_control        -0.47416 -0.31107 -0.96473 -0.925070  0.89119  3.1870
# 120_control       -1.48090 -1.67250 -2.15810 -0.826770 -1.36390  6.3541
# 258_CD_plain      -1.56310 -1.67960 -1.38710 -0.013321 -1.14760  3.4411
# ...                    ...      ...      ...       ...      ...     ...
# 107_CD_plain      -1.11610 -1.74270 -0.53816 -1.745400 -1.30290  1.3587
# 279_CD_plain      -7.68410 -8.46800 -8.22400 -8.402600 -8.83370  7.2140
# 179_CD_plain      -1.26450 -0.73212 -0.60830 -0.691130 -0.87280  3.0501
# 70_CD_deep_ulcer  -4.27330 -4.14290 -3.11200 -4.005200 -2.91910  4.9455
# 256_CD_deep_ulcer -2.72990 -2.61730 -1.71510 -0.812990 -1.44460  3.9599
#
# Gene_Symbol              C6   CEACAM7  CHI3L1    ABCC2  ...     TAF15  \
# 55_control         2.953400   3.16100  0.8389 -1.76750  ...  0.132720
# 168_CD_plain      -2.640900   1.40780  2.9396 -3.14160  ... -0.875480
# 72_control         0.094616  -0.43266 -1.1968 -1.21560  ... -0.153490
# 120_control       -0.465450   1.36980  5.3490 -0.60178  ... -0.485040
# 258_CD_plain      -2.164800   1.30790  1.6726 -0.25756  ... -0.188300
# ...                     ...       ...     ...      ...  ...       ...
# 107_CD_plain      -3.166600   4.08550  2.9676 -1.82800  ... -0.058156
# 279_CD_plain      -5.177400  11.71480  4.5251 -5.26600  ... -0.485480
# 179_CD_plain      -1.596200   2.46790  2.9987 -0.73609  ... -0.160410
# 70_CD_deep_ulcer  -1.944200   3.96700  4.7686 -3.55790  ...  0.020804
# 256_CD_deep_ulcer -5.177400   3.38010  1.6608 -1.31380  ... -0.293770
#
# Gene_Symbol         ZFYVE20  LOC100420253   LY6G5B  C5orf58  RSL24D1P1  \
# 55_control         0.102570           0.0 -1.03740  0.78394        0.0
# 168_CD_plain      -0.364270           0.0 -3.29260 -1.94920        0.0
# 72_control        -0.146870           0.0 -0.77854 -2.04530        0.0
# 120_control        0.000521           0.0  0.14277  0.49289        0.0
# 258_CD_plain       0.024540           0.0  0.43126  0.52019        0.0
# ...                     ...           ...      ...      ...        ...
# 107_CD_plain      -0.169060           0.0 -0.26242  0.95321        0.0
# 279_CD_plain       0.119700           0.0 -0.88157  0.81030        0.0
# 179_CD_plain      -0.056853           0.0  0.39592  1.43170        0.0
# 70_CD_deep_ulcer  -0.118210           0.0  0.63054 -0.08934        0.0
# 256_CD_deep_ulcer -0.075635           0.0 -0.50832 -0.75738        0.0
#
# Gene_Symbol           MIEN1  PCBP1_AS1  LOC100133165  DNAJB8
# 55_control         0.429040    0.95376           0.0  1.7602
# 168_CD_plain       0.634970   -0.12304           0.0  0.0000
# 72_control         1.220600    0.31210           0.0  0.0000
# 120_control        0.044507    0.17639           0.0  0.0000
# 258_CD_plain      -0.294330    0.31456           0.0  0.0000
# ...                     ...        ...           ...     ...
# 107_CD_plain       0.075207   -0.49408           0.0  0.0000
# 279_CD_plain       0.056488   -0.92444           0.0  0.0000
# 179_CD_plain      -0.295630    0.44625           0.0  0.0000
# 70_CD_deep_ulcer   0.226690    0.25432           0.0  0.0000
# 256_CD_deep_ulcer -0.076394    0.14148           0.0  0.0000
#
# [260 rows x 219 columns]

# %%
# train:val:test 70:30

split_pt = int(0.7*len(shuffled_df))
# split_pt_test = int(0.7*len(shuffled_df))

x_train = shuffled_df[:split_pt]
# x_val = shuffled_df[split_pt_train:split_pt_test]
x_test = shuffled_df[split_pt:]

# print("train set:",x_train.shape)
# print("val set:",x_val.shape)
# print("test set:",x_test.shape)

# %% [markdown]
# # Feature scaling

# %%
from sklearn.preprocessing import MinMaxScaler
# link to california housing dataset autoecncoder tutorial

def scale_datasets(x_train, x_test):
  """
  Standard Scale test and train data
  """
  standard_scaler = MinMaxScaler()
  x_train_scaled = pd.DataFrame(
      standard_scaler.fit_transform(x_train),
      index = x_train.index,
      columns=x_train.columns
  )
#   x_val_scaled = pd.DataFrame(
#       standard_scaler.transform(x_val),
#       index = x_val.index,
#       columns = x_val.columns
#   )
  x_test_scaled = pd.DataFrame(
      standard_scaler.transform(x_test),
      index = x_test.index,
      columns = x_test.columns
  )
  return x_train_scaled, x_test_scaled
  
x_train_scaled, x_test_scaled = scale_datasets(x_train, x_test)

# %%
x_train_scaled
# Out:
# Gene_Symbol      AADAC     APOA1     APOA4      APOB     APOC3      AQP9  \
# 55_control    0.702813  0.799052  0.719665  0.729547  0.794953  0.256451
# 168_CD_plain  0.751408  0.603707  0.622768  0.627712  0.606860  0.520576
# 72_control    0.786508  0.755331  0.739605  0.756170  0.819875  0.391132
# 120_control   0.707491  0.662993  0.648072  0.764621  0.654276  0.633929
# 258_CD_plain  0.701039  0.662511  0.707208  0.834562  0.670160  0.410612
# ...                ...       ...       ...       ...       ...       ...
# 15_CD_plain   0.382762  0.384030  0.377332  0.360165  0.300915  0.340090
# 182_CD_plain  0.679910  0.584723  0.722426  0.643867  0.740014  0.650358
# 164_CD_plain  0.754656  0.556562  0.694062  0.748334  0.535534  0.133869
# 53_CD_plain   0.591140  0.585802  0.750282  0.753309  0.603372  0.469634
# 97_CD_plain   0.817125  0.782223  0.854442  0.867360  0.793421  0.726438
#
# Gene_Symbol         C6   CEACAM7    CHI3L1     ABCC2  ...     TAF15   ZFYVE20  \
# 55_control    1.000000  0.363133  0.374212  0.611161  ...  0.468042  0.335792
# 168_CD_plain  0.311962  0.251356  0.553554  0.441131  ...  0.000000  0.159464
# 72_control    0.648401  0.134017  0.200420  0.679453  ...  0.335173  0.241577
# 120_control   0.579519  0.248934  0.759250  0.755407  ...  0.181256  0.297248
# 258_CD_plain  0.370517  0.244987  0.445387  0.798000  ...  0.319013  0.306320
# ...                ...       ...       ...       ...  ...       ...       ...
# 15_CD_plain   0.077348  0.890965  0.261140  0.205779  ...  0.209212  0.301844
# 182_CD_plain  0.468650  0.295686  0.649939  0.609862  ...  0.408592  0.042243
# 164_CD_plain  0.319071  0.154562  0.440487  0.824013  ...  0.514164  0.364434
# 53_CD_plain   0.213239  0.348800  0.485094  0.722492  ...  0.428242  0.315197
# 97_CD_plain   0.246396  0.228774  0.611752  0.699944  ...  0.261123  0.099541
#
# Gene_Symbol   LOC100420253    LY6G5B   C5orf58  RSL24D1P1     MIEN1  \
# 55_control             0.0  0.609518  0.535456        0.0  0.543158
# 168_CD_plain           0.0  0.173529  0.018188        0.0  0.623796
# 72_control             0.0  0.659563  0.000000        0.0  0.853118
# 120_control            0.0  0.837676  0.480372        0.0  0.392582
# 258_CD_plain           0.0  0.893448  0.485539        0.0  0.259900
# ...                    ...       ...       ...        ...       ...
# 15_CD_plain            0.0  0.643267  0.143476        0.0  0.262892
# 182_CD_plain           0.0  0.765285  0.527984        0.0  0.413798
# 164_CD_plain           0.0  0.930260  0.481733        0.0  0.273699
# 53_CD_plain            0.0  0.877855  0.628071        0.0  0.183718
# 97_CD_plain            0.0  0.156787  0.293838        0.0  0.561414
#
# Gene_Symbol   PCBP1_AS1  LOC100133165  DNAJB8
# 55_control     0.622641           0.0     1.0
# 168_CD_plain   0.301179           0.0     0.0
# 72_control     0.431083           0.0     0.0
# 120_control    0.390569           0.0     0.0
# 258_CD_plain   0.431818           0.0     0.0
# ...                 ...           ...     ...
# 15_CD_plain    0.189790           0.0     0.0
# 182_CD_plain   0.270021           0.0     0.0
# 164_CD_plain   0.433093           0.0     0.0
# 53_CD_plain    0.302030           0.0     0.0
# 97_CD_plain    0.027077           0.0     0.0
#
# [182 rows x 219 columns]

# %%
x_train_scaled.to_csv('260_sample_train_scaled.csv', index_label = "Patient_ID")
x_test_scaled.to_csv('260_sample_test_scaled.csv', index_label = "Patient_ID")

# %% [markdown]
# # Autoencoder model

# %%
from tensorflow.keras import Input
from tensorflow.keras.layers import Conv1D, Conv2D, LeakyReLU, MaxPool1D, AveragePooling1D, UpSampling1D, Flatten, Dense, Reshape, BatchNormalization
# https://towardsdatascience.com/improve-your-model-performance-with-auto-encoders-d4ee543b4154
from tensorflow.keras import initializers

# n_inputs = 120
# bottleneck_features = 32

class AutoEncoder(Model):

    def __init__(self, n_inputs, init_fn, n_bottleneck=32):

        super().__init__()

        self.encoder = Sequential(
            [

                Input(shape=(n_inputs,)),
                # encoder level 1
#                 Dense(n_inputs*2, kernel_initializer=init_fn,
#     bias_initializer=initializers.Zeros()),
                Dense(n_inputs*2),
                BatchNormalization(),
                LeakyReLU(),
                # encoder level 2
                Dense(n_inputs),
                BatchNormalization(),
                LeakyReLU(),
                # bottleneck
                Dense(n_bottleneck)
            ]
        )

        self.decoder = Sequential(
            [
                
                # define decoder, level 1
                Dense(n_inputs),
                BatchNormalization(),
                LeakyReLU(),
                # decoder level 2,
                Dense(n_inputs*2),
                BatchNormalization(),
                LeakyReLU(),
                # output layer
                Dense(n_inputs, activation='linear')
            ]
        )

    def call(self, inputs):

        encoded = self.encoder(inputs)
        decoded = self.decoder(encoded)
        return decoded

# %% [markdown]
# ## Hyperparameter grid search

# %%
from sklearn.metrics import make_scorer, mean_squared_error
def loss_func(x_true, x_pred):
#     print("x_true shape:", x_true.shape)
#     print(type(x_true))
#     print("x_pred shape:", x_pred.shape)
#     print(type(x_pred))
#     print("loss between",x_true,"and",x_pred,"is",mean_squared_error(x_true, x_pred))
    total_loss = 0
    x_true = x_true.values
    num_patients = x_true.shape[0]
    for i in range(num_patients):
        loss_item = mean_squared_error(x_true[i], x_pred[i])
        print("loss item:",loss_item)
        total_loss += loss_item
#     print("total loss:",total_loss)
    mse_loss = total_loss / num_patients
    print("mse average loss:",mse_loss)
#     if mse_loss < 0:
#         print("NEGATIVE")
    
    return mse_loss

my_scorer = make_scorer(loss_func, greater_is_better=False)

# %%
# initialisation functions

# https://stackoverflow.com/questions/49433936/how-do-i-initialize-weights-in-pytorch

        
def get_init(model, init_fn):
    if init_fn == 'init_xavier_uniform':
        initializer = tf.keras.initializers.GlorotUniform()
    elif init_fn == 'zeros':
        initializer = tf.keras.initializers.Zeros()
#     if init_fn == 'init_he':
#         model.apply(init_he)
#     if init_fn == 'zeros':
#         model.apply(init_zeros)
#     if init_fn == 'ones':
#         model.apply(init_ones)
#     if init_fn == 'normal':
#         model.apply(init_normal)
#     if init_fn == 'uniform':
#         model.apply(init_uniform)
        
    return initializer

# %%
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import GridSearchCV

from keras.optimizers import Adam, SGD, Adadelta


# def create_model(optimizer, learn_rate, init):
# #     <return a compiled but untrained keras model>
#     n_bottleneck = 32 ####
#     init_fn = get_init(model, init)
    
#     if optimizer=="Adam":
#         opt = Adam(learning_rate=learn_rate)
#     elif optimizer=="SGD":
#         opt = SGD(learning_rate=learn_rate)
#     else:
#         opt = Adadelta(learning_rate=lrn_rate) # need some default 
#     auto_encoder = AutoEncoder(len(x_train_scaled.columns), init_fn, n_bottleneck)
#     auto_encoder.compile(optimizer=opt, loss='mse', metrics=['mse'])
#     return auto_encoder

# # scorer = make_scorer(mean_squared_error, greater_is_better=False)
# model = KerasRegressor(build_fn = create_model)
# #now write out all the parameters you want to try out for the grid search
# # activation = ['relu', 'tanh', 'sigmoid'...]
# # learn_rate = [0.1, 0.2, 0.3]
# learn_rate = [0.001, 0.01, 0.1, 0.2]
# init = ['uniform', 'normal', 'zero']
# batch_size = [16, 32, 40, 60, 80, 100]
# optimizer = ['SGD', 'adam']
# # param_grid = dict(activation=activation, learn_rate=learn_rate, init=init, optimizer=optimizer)
# # param_grid = dict(optimizer=optimizer)
# # param_grid = {'epochs':[10,100]}
# # param_grid = {'optimizer':['SGD', 'Adam'], 'epochs':[80,100], 'batch_size':batch_size, 'learn_rate':learn_rate}
# param_grid = {'optimizer':['Adam'], 'epochs':[100], 'batch_size':[32], 'learn_rate':[0.01], 'init':['init_xavier_uniform', 'zeros']}
# grid = GridSearchCV(estimator=model, scoring=my_scorer, param_grid=param_grid)
# result = grid.fit(x_train_scaled, x_train_scaled)
# print(result)

# %%
# grid.best_params_

# %%
# grid.best_score_

# %% [markdown]
# ## Training best model

# %%
# define autoencoder model


# auto_encoder = AutoEncoder(len(x_train_scaled.columns))

n_bottleneck = 32
initializer = tf.keras.initializers.GlorotUniform()
auto_encoder = AutoEncoder(len(x_train_scaled.columns),initializer, n_bottleneck)
opt = Adam(learning_rate=0.01)
auto_encoder.compile(optimizer='adam', loss='mse', metrics=['mse'])

# %%
split_pt = int(0.8*len(x_train_scaled))
# split_pt_test = int(0.7*len(shuffled_df))

x_val_scaled = x_train_scaled[split_pt:]
x_train_scaled_part = x_train_scaled[:split_pt]
# x_val = shuffled_df[split_pt_train:split_pt_test]
x_val_scaled
# Out:
# Gene_Symbol           AADAC     APOA1     APOA4      APOB     APOC3      AQP9  \
# 217_CD_deep_ulcer  0.606202  0.552086  0.569016  0.578221  0.538787  0.896575
# 85_control         0.957499  0.847428  0.864091  0.904289  0.814344  0.000000
# 175_CD_plain       0.820595  0.794473  0.873303  0.804521  0.787592  0.406395
# 1_CD_plain         0.754556  0.569802  0.743179  0.722832  0.660621  0.631430
# 156_CD_plain       0.880244  0.831975  0.878531  0.813158  0.793081  0.230754
# 157_CD_plain       0.483086  0.375966  0.502569  0.372005  0.400784  0.720458
# 109_CD_deep_ulcer  0.588990  0.346462  0.321700  0.330742  0.342383  0.855001
# 73_CD_plain        0.780746  0.737652  0.800068  0.844755  0.671768  0.386800
# 71_CD_plain        0.716674  0.624889  0.672977  0.831450  0.695532  0.409623
# 141_CD_plain       0.751728  0.788205  0.819058  0.834981  0.750507  0.519595
# 139_CD_deep_ulcer  0.413318  0.270736  0.330598  0.364490  0.213206  0.839507
# 205_CD_plain       0.689917  0.624292  0.691078  0.772835  0.667024  0.372441
# 32_CD_plain        0.767771  0.820067  0.787365  0.720115  0.770098  0.385374
# 39_control         0.759528  0.654325  0.640256  0.734904  0.573558  0.294414
# 207_CD_plain       0.618972  0.442475  0.537553  0.536847  0.533317  0.565431
# 133_CD_deep_ulcer  0.423231  0.189177  0.201655  0.314122  0.130506  0.869329
# 162_CD_plain       0.665845  0.700547  0.782192  0.830080  0.737408  0.327111
# 195_CD_plain       0.812560  0.801711  0.905105  0.686299  0.842016  0.361456
# 36_control         0.812336  0.874938  0.844565  0.745041  0.854888  0.232486
# 237_CD_plain       0.770299  0.803294  0.830874  0.831959  0.754635  0.600826
# 7_CD_plain         0.451314  0.137677  0.233701  0.247797  0.148299  0.561698
# 108_CD_plain       0.759696  0.842957  0.891460  0.799771  0.857158  0.239762
# 140_CD_plain       0.616602  0.477370  0.579271  0.560182  0.565370  0.673610
# 185_CD_plain       0.666724  0.401725  0.532253  0.568884  0.391480  0.701224
# 86_control         0.884630  0.680125  0.777541  0.862064  0.693909  0.000000
# 117_control        0.842485  0.765624  0.790669  0.848277  0.725625  0.255585
# 26_CD_plain        0.735605  0.720005  0.701333  0.690048  0.625828  0.000000
# 303_CD_plain       0.781692  0.706428  0.762380  0.824484  0.669462  0.414951
# 35_control         0.868755  0.777184  0.832517  0.826357  0.724312  0.000000
# 148_CD_deep_ulcer  0.820946  0.897985  0.934965  0.816291  0.919488  0.465280
# 28_control         0.913545  0.873595  0.907560  0.820765  0.852810  0.229535
# 67_control         0.935844  0.848575  0.854504  0.864477  0.836009  0.381955
# 15_CD_plain        0.382762  0.384030  0.377332  0.360165  0.300915  0.340090
# 182_CD_plain       0.679910  0.584723  0.722426  0.643867  0.740014  0.650358
# 164_CD_plain       0.754656  0.556562  0.694062  0.748334  0.535534  0.133869
# 53_CD_plain        0.591140  0.585802  0.750282  0.753309  0.603372  0.469634
# 97_CD_plain        0.817125  0.782223  0.854442  0.867360  0.793421  0.726438
#
# Gene_Symbol              C6   CEACAM7    CHI3L1     ABCC2  ...     TAF15  \
# 217_CD_deep_ulcer  0.123592  0.553864  0.911255  0.429141  ...  0.286851
# 85_control         0.641445  0.212172  0.000000  0.999852  ...  0.368050
# 175_CD_plain       0.418544  0.144439  0.277901  0.738467  ...  0.319408
# 1_CD_plain         0.205613  0.507660  0.584817  0.619118  ...  0.202801
# 156_CD_plain       0.441998  0.064393  0.420774  0.792305  ...  0.356050
# 157_CD_plain       0.030514  0.308137  0.739444  0.252577  ...  0.523388
# 109_CD_deep_ulcer  0.210299  0.626730  0.916369  0.124618  ...  0.204770
# 73_CD_plain        0.842254  0.223941  0.571090  0.844974  ...  0.336023
# 71_CD_plain        0.371587  0.054275  0.508119  0.802600  ...  0.225535
# 141_CD_plain       0.301496  0.354653  0.558335  0.712313  ...  0.343283
# 139_CD_deep_ulcer  0.155717  0.260792  0.934289  0.259086  ...  0.404258
# 205_CD_plain       0.763000  0.086433  0.581420  0.720892  ...  0.322927
# 32_CD_plain        0.372276  0.262310  0.306905  0.617311  ...  0.654159
# 39_control         0.481441  0.122056  0.461617  0.725358  ...  0.539214
# 207_CD_plain       0.000000  0.508540  0.680161  0.448741  ...  0.350999
# 133_CD_deep_ulcer  0.090655  0.540845  0.883842  0.351618  ...  0.311567
# 162_CD_plain       0.782666  0.000000  0.467089  0.920609  ...  0.328024
# 195_CD_plain       0.138978  0.321245  0.478461  0.614304  ...  0.442629
# 36_control         0.605814  0.000000  0.293481  0.624624  ...  0.612883
# 237_CD_plain       0.598431  0.328877  0.467874  0.714126  ...  0.306609
# 7_CD_plain         0.119865  0.405830  0.831919  0.336868  ...  0.459895
# 108_CD_plain       0.328147  0.331000  0.585850  0.806150  ...  0.384348
# 140_CD_plain       0.479104  0.361322  0.820240  0.380486  ...  0.501727
# 185_CD_plain       0.294743  0.505799  0.740255  0.473439  ...  0.411655
# 86_control         0.526825  0.061301  0.250915  0.938453  ...  0.304065
# 117_control        0.677118  0.180838  0.246953  0.911550  ...  0.436519
# 26_CD_plain        0.546467  0.146403  0.398586  0.642084  ...  0.423427
# 303_CD_plain       0.445122  0.325447  0.398014  0.760045  ...  0.265728
# 35_control         0.578185  0.000000  0.391885  0.823626  ...  0.534572
# 148_CD_deep_ulcer  0.455884  0.306422  0.437516  0.705810  ...  0.298452
# 28_control         0.605247  0.100676  0.270851  0.737150  ...  0.490622
# 67_control         0.576439  0.458664  0.377453  0.905464  ...  0.409630
# 15_CD_plain        0.077348  0.890965  0.261140  0.205779  ...  0.209212
# 182_CD_plain       0.468650  0.295686  0.649939  0.609862  ...  0.408592
# 164_CD_plain       0.319071  0.154562  0.440487  0.824013  ...  0.514164
# 53_CD_plain        0.213239  0.348800  0.485094  0.722492  ...  0.428242
# 97_CD_plain        0.246396  0.228774  0.611752  0.699944  ...  0.261123
#
# Gene_Symbol         ZFYVE20  LOC100420253    LY6G5B   C5orf58  RSL24D1P1  \
# 217_CD_deep_ulcer  0.265839           0.0  0.773677  0.781880        0.0
# 85_control         0.326319           0.0  0.831184  0.219528        0.0
# 175_CD_plain       0.097157           0.0  0.820013  0.264323        0.0
# 1_CD_plain         0.214885           0.0  0.427850  0.001003        0.0
# 156_CD_plain       0.155891           0.0  0.826918  0.328886        0.0
# 157_CD_plain       0.099945           0.0  0.850346  0.076138        0.0
# 109_CD_deep_ulcer  0.023051           0.0  0.244035  0.161002        0.0
# 73_CD_plain        0.295570           0.0  0.867278  0.142416        0.0
# 71_CD_plain        0.328678           0.0  0.816139  0.625308        0.0
# 141_CD_plain       0.184834           0.0  0.730216  0.424212        0.0
# 139_CD_deep_ulcer  0.207984           0.0  0.796157  0.750653        0.0
# 205_CD_plain       0.249483           0.0  0.858076  0.554379        0.0
# 32_CD_plain        0.073011           0.0  0.847537  0.000000        0.0
# 39_control         0.328436           0.0  0.876521  0.471074        0.0
# 207_CD_plain       0.245656           0.0  0.814190  0.542765        0.0
# 133_CD_deep_ulcer  0.323167           0.0  0.830805  1.000000        0.0
# 162_CD_plain       0.352003           0.0  0.936896  0.721148        0.0
# 195_CD_plain       0.130256           0.0  0.736688  0.235626        0.0
# 36_control         0.161492           0.0  0.693870  0.052103        0.0
# 237_CD_plain       0.275208           0.0  0.890255  0.586074        0.0
# 7_CD_plain         0.327353           0.0  0.907838  0.660055        0.0
# 108_CD_plain       0.147230           0.0  0.842057  0.043359        0.0
# 140_CD_plain       0.035440           0.0  0.736678  0.552599        0.0
# 185_CD_plain       0.213242           0.0  0.764566  0.476583        0.0
# 86_control         0.331081           0.0  0.866895  0.552926        0.0
# 117_control        0.239983           0.0  0.947357  0.278517        0.0
# 26_CD_plain        0.241770           0.0  0.822124  0.263360        0.0
# 303_CD_plain       0.296936           0.0  0.795098  0.171430        0.0
# 35_control         0.083250           0.0  0.772660  0.019967        0.0
# 148_CD_deep_ulcer  0.209982           0.0  0.794165  0.521869        0.0
# 28_control         0.184989           0.0  0.785232  0.017374        0.0
# 67_control         0.208467           0.0  0.857809  0.306420        0.0
# 15_CD_plain        0.301844           0.0  0.643267  0.143476        0.0
# 182_CD_plain       0.042243           0.0  0.765285  0.527984        0.0
# 164_CD_plain       0.364434           0.0  0.930260  0.481733        0.0
# 53_CD_plain        0.315197           0.0  0.877855  0.628071        0.0
# 97_CD_plain        0.099541           0.0  0.156787  0.293838        0.0
#
# Gene_Symbol           MIEN1  PCBP1_AS1  LOC100133165  DNAJB8
# 217_CD_deep_ulcer  0.390841   0.300421           0.0     0.0
# 85_control         0.434044   0.249954           0.0     0.0
# 175_CD_plain       0.556358   0.465582           0.0     0.0
# 1_CD_plain         0.394301   0.009016           0.0     0.0
# 156_CD_plain       0.578193   0.383996           0.0     0.0
# 157_CD_plain       0.501161   0.294656           0.0     0.0
# 109_CD_deep_ulcer  0.597243   0.000000           0.0     0.0
# 73_CD_plain        0.296446   0.462579           0.0     0.0
# 71_CD_plain        0.382301   0.470281           0.0     0.0
# 141_CD_plain       0.475227   0.252252           0.0     0.0
# 139_CD_deep_ulcer  0.242628   0.267469           0.0     0.0
# 205_CD_plain       0.384000   0.451724           0.0     0.0
# 32_CD_plain        0.932061   0.403759           0.0     0.0
# 39_control         0.125110   0.344248           0.0     0.0
# 207_CD_plain       0.313476   0.354501           0.0     0.0
# 133_CD_deep_ulcer  0.171254   0.373684           0.0     0.0
# 162_CD_plain       0.200368   0.394029           0.0     0.0
# 195_CD_plain       0.672905   0.334888           0.0     0.0
# 36_control         0.685192   0.440869           0.0     0.0
# 237_CD_plain       0.378769   0.310851           0.0     0.0
# 7_CD_plain         0.123751   0.331964           0.0     0.0
# 108_CD_plain       0.614876   0.329121           0.0     0.0
# 140_CD_plain       0.496231   0.145747           0.0     0.0
# 185_CD_plain       0.279244   0.293023           0.0     0.0
# 86_control         0.301118   0.408849           0.0     0.0
# 117_control        0.377739   0.453954           0.0     0.0
# 26_CD_plain        0.319695   0.270562           0.0     0.0
# 303_CD_plain       0.238152   0.366623           0.0     0.0
# 35_control         0.334790   0.219109           0.0     0.0
# 148_CD_deep_ulcer  1.000000   0.539350           0.0     0.0
# 28_control         0.662575   0.341922           0.0     0.0
# 67_control         0.543671   0.391775           0.0     0.0
# 15_CD_plain        0.262892   0.189790           0.0     0.0
# 182_CD_plain       0.413798   0.270021           0.0     0.0
# 164_CD_plain       0.273699   0.433093           0.0     0.0
# 53_CD_plain        0.183718   0.302030           0.0     0.0
# 97_CD_plain        0.561414   0.027077           0.0     0.0
#
# [37 rows x 219 columns]

# %%
x_train_scaled_part
# Out:
# Gene_Symbol           AADAC     APOA1     APOA4      APOB     APOC3      AQP9  \
# 55_control         0.702813  0.799052  0.719665  0.729547  0.794953  0.256451
# 168_CD_plain       0.751408  0.603707  0.622768  0.627712  0.606860  0.520576
# 72_control         0.786508  0.755331  0.739605  0.756170  0.819875  0.391132
# 120_control        0.707491  0.662993  0.648072  0.764621  0.654276  0.633929
# 258_CD_plain       0.701039  0.662511  0.707208  0.834562  0.670160  0.410612
# ...                     ...       ...       ...       ...       ...       ...
# 174_CD_plain       0.507857  0.504568  0.553361  0.622493  0.537040  0.428029
# 274_CD_plain       0.884177  0.785462  0.883061  0.912750  0.767023  0.153630
# 160_CD_plain       0.847110  0.735907  0.829303  0.828346  0.720977  0.539274
# 227_CD_plain       0.690145  0.466851  0.655650  0.637548  0.579492  0.666066
# 150_CD_deep_ulcer  0.623399  0.694009  0.720248  0.641013  0.718839  0.518568
#
# Gene_Symbol              C6   CEACAM7    CHI3L1     ABCC2  ...     TAF15  \
# 55_control         1.000000  0.363133  0.374212  0.611161  ...  0.468042
# 168_CD_plain       0.311962  0.251356  0.553554  0.441131  ...  0.000000
# 72_control         0.648401  0.134017  0.200420  0.679453  ...  0.335173
# 120_control        0.579519  0.248934  0.759250  0.755407  ...  0.181256
# 258_CD_plain       0.370517  0.244987  0.445387  0.798000  ...  0.319013
# ...                     ...       ...       ...       ...  ...       ...
# 174_CD_plain       0.000000  0.199162  0.627999  0.538031  ...  0.411994
# 274_CD_plain       0.421927  0.339556  0.067453  0.968904  ...  0.258458
# 160_CD_plain       0.344702  0.211948  0.437431  0.815641  ...  0.467039
# 227_CD_plain       0.156565  0.411542  0.618804  0.546037  ...  0.362152
# 150_CD_deep_ulcer  0.320350  0.446448  0.785664  0.518072  ...  0.471106
#
# Gene_Symbol         ZFYVE20  LOC100420253    LY6G5B   C5orf58  RSL24D1P1  \
# 55_control         0.335792           0.0  0.609518  0.535456        0.0
# 168_CD_plain       0.159464           0.0  0.173529  0.018188        0.0
# 72_control         0.241577           0.0  0.659563  0.000000        0.0
# 120_control        0.297248           0.0  0.837676  0.480372        0.0
# 258_CD_plain       0.306320           0.0  0.893448  0.485539        0.0
# ...                     ...           ...       ...       ...        ...
# 174_CD_plain       0.294706           0.0  0.947694  0.682142        0.0
# 274_CD_plain       0.339717           0.0  0.830774  0.232066        0.0
# 160_CD_plain       0.296531           0.0  0.811662  0.555700        0.0
# 227_CD_plain       0.104700           0.0  0.792418  0.573551        0.0
# 150_CD_deep_ulcer  0.092564           0.0  0.643045  0.139161        0.0
#
# Gene_Symbol           MIEN1  PCBP1_AS1  LOC100133165  DNAJB8
# 55_control         0.543158   0.622641           0.0     1.0
# 168_CD_plain       0.623796   0.301179           0.0     0.0
# 72_control         0.853118   0.431083           0.0     0.0
# 120_control        0.392582   0.390569           0.0     0.0
# 258_CD_plain       0.259900   0.431818           0.0     0.0
# ...                     ...        ...           ...     ...
# 174_CD_plain       0.270962   0.418646           0.0     0.0
# 274_CD_plain       0.345638   0.295782           0.0     0.0
# 160_CD_plain       0.393700   0.319821           0.0     0.0
# 227_CD_plain       0.459595   0.281912           0.0     0.0
# 150_CD_deep_ulcer  0.815017   0.319464           0.0     0.0
#
# [145 rows x 219 columns]

# %%
history = auto_encoder.fit(
    x_train_scaled_part, 
    x_train_scaled_part, 
    epochs=100, 
    batch_size=32, 
    validation_data=(x_val_scaled, x_val_scaled)
)

# history = auto_encoder.fit(
#     x_train_scaled_part, 
#     x_train_scaled_part, 
#     epochs=100, 
#     batch_size=16, 
#     validation_data=(x_val_scaled, x_val_scaled)
# )

# history = auto_encoder.fit(
#     x_train_scaled, 
#     x_train_scaled, 
#     epochs=100, 
#     batch_size=32, 
#     validation_data=(x_test_scaled, x_test_scaled)
# )
# Out:
# Epoch 1/100
# 5/5 [==============================] - 1s 80ms/step - loss: 0.6768 - mse: 0.6768 - val_loss: 0.2023 - val_mse: 0.2023
# Epoch 2/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.1885 - mse: 0.1885 - val_loss: 0.1322 - val_mse: 0.1322
# Epoch 3/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0926 - mse: 0.0926 - val_loss: 0.0973 - val_mse: 0.0973
# Epoch 4/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0662 - mse: 0.0662 - val_loss: 0.0928 - val_mse: 0.0928
# Epoch 5/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0436 - mse: 0.0436 - val_loss: 0.1051 - val_mse: 0.1051
# Epoch 6/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0292 - mse: 0.0292 - val_loss: 0.1064 - val_mse: 0.1064
# Epoch 7/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0286 - mse: 0.0286 - val_loss: 0.0928 - val_mse: 0.0928
# Epoch 8/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0209 - mse: 0.0209 - val_loss: 0.0770 - val_mse: 0.0770
# Epoch 9/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0201 - mse: 0.0201 - val_loss: 0.0685 - val_mse: 0.0685
# Epoch 10/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0175 - mse: 0.0175 - val_loss: 0.0652 - val_mse: 0.0652
# Epoch 11/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0174 - mse: 0.0174 - val_loss: 0.0636 - val_mse: 0.0636
# Epoch 12/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0177 - mse: 0.0177 - val_loss: 0.0586 - val_mse: 0.0586
# Epoch 13/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0163 - mse: 0.0163 - val_loss: 0.0542 - val_mse: 0.0542
# Epoch 14/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0145 - mse: 0.0145 - val_loss: 0.0505 - val_mse: 0.0505
# Epoch 15/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0144 - mse: 0.0144 - val_loss: 0.0499 - val_mse: 0.0499
# Epoch 16/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0140 - mse: 0.0140 - val_loss: 0.0479 - val_mse: 0.0479
# Epoch 17/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0152 - mse: 0.0152 - val_loss: 0.0414 - val_mse: 0.0414
# Epoch 18/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0413 - val_mse: 0.0413
# Epoch 19/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0143 - mse: 0.0143 - val_loss: 0.0403 - val_mse: 0.0403
# Epoch 20/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0360 - val_mse: 0.0360
# Epoch 21/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0352 - val_mse: 0.0352
# Epoch 22/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0317 - val_mse: 0.0317
# Epoch 23/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0139 - mse: 0.0139 - val_loss: 0.0308 - val_mse: 0.0308
# Epoch 24/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0289 - val_mse: 0.0289
# Epoch 25/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0127 - mse: 0.0127 - val_loss: 0.0275 - val_mse: 0.0275
# Epoch 26/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0142 - mse: 0.0142 - val_loss: 0.0277 - val_mse: 0.0277
# Epoch 27/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0232 - val_mse: 0.0232
# Epoch 28/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0232 - val_mse: 0.0232
# Epoch 29/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0130 - mse: 0.0130 - val_loss: 0.0225 - val_mse: 0.0225
# Epoch 30/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0235 - val_mse: 0.0235
# Epoch 31/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0127 - mse: 0.0127 - val_loss: 0.0247 - val_mse: 0.0247
# Epoch 32/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0207 - val_mse: 0.0207
# Epoch 33/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0124 - mse: 0.0124 - val_loss: 0.0212 - val_mse: 0.0212
# Epoch 34/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0207 - val_mse: 0.0207
# Epoch 35/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0196 - val_mse: 0.0196
# Epoch 36/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0203 - val_mse: 0.0203
# Epoch 37/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0196 - val_mse: 0.0196
# Epoch 38/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0182 - val_mse: 0.0182
# Epoch 39/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0175 - val_mse: 0.0175
# Epoch 40/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0173 - val_mse: 0.0173
# Epoch 41/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0157 - val_mse: 0.0157
# Epoch 42/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0173 - val_mse: 0.0173
# Epoch 43/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0160 - val_mse: 0.0160
# Epoch 44/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0139 - val_mse: 0.0139
# Epoch 45/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0161 - val_mse: 0.0161
# Epoch 46/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0152 - val_mse: 0.0152
# Epoch 47/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0144 - val_mse: 0.0144
# Epoch 48/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0156 - val_mse: 0.0156
# Epoch 49/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0142 - val_mse: 0.0142
# Epoch 50/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0140 - val_mse: 0.0140
# Epoch 51/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0096 - mse: 0.0096 - val_loss: 0.0125 - val_mse: 0.0125
# Epoch 52/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0144 - val_mse: 0.0144
# Epoch 53/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0127 - val_mse: 0.0127
# Epoch 54/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0122 - val_mse: 0.0122
# Epoch 55/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0130 - mse: 0.0130 - val_loss: 0.0134 - val_mse: 0.0134
# Epoch 56/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0143 - val_mse: 0.0143
# Epoch 57/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0129 - val_mse: 0.0129
# Epoch 58/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0121 - val_mse: 0.0121
# Epoch 59/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 60/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 61/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0118 - val_mse: 0.0118
# Epoch 62/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 63/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 64/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0124 - val_mse: 0.0124
# Epoch 65/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 66/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0122 - val_mse: 0.0122
# Epoch 67/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 68/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0122 - val_mse: 0.0122
# Epoch 69/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 70/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 71/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 72/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 73/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 74/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 75/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 76/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 77/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0097 - mse: 0.0097 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 78/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 79/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0096 - val_mse: 0.0096
# Epoch 80/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 81/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 82/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0097 - val_mse: 0.0097
# Epoch 83/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 84/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0096 - val_mse: 0.0096
# Epoch 85/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 86/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 87/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 88/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0094 - val_mse: 0.0094
# Epoch 89/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 90/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 91/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0094 - val_mse: 0.0094
# Epoch 92/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0097 - val_mse: 0.0097
# Epoch 93/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0091 - val_mse: 0.0091
# Epoch 94/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 95/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 96/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 97/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 98/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 99/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 100/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0101 - mse: 0.0101 - val_loss: 0.0110 - val_mse: 0.0110

# %%
auto_encoder.encoder.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 438)               96360
#
#  batch_normalization (BatchN  (None, 438)              1752
#  ormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 438)               0
#
#  dense_1 (Dense)             (None, 219)               96141
#
#  batch_normalization_1 (Batc  (None, 219)              876
#  hNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 219)               0
#
#  dense_2 (Dense)             (None, 32)                7040
#
# =================================================================
# Total params: 202,169
# Trainable params: 200,855
# Non-trainable params: 1,314
# _________________________________________________________________

# %%
auto_encoder.decoder.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 219)               7227
#
#  batch_normalization_2 (Batc  (None, 219)              876
#  hNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 219)               0
#
#  dense_4 (Dense)             (None, 438)               96360
#
#  batch_normalization_3 (Batc  (None, 438)              1752
#  hNormalization)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 438)               0
#
#  dense_5 (Dense)             (None, 219)               96141
#
# =================================================================
# Total params: 202,356
# Trainable params: 201,042
# Non-trainable params: 1,314
# _________________________________________________________________

# %%
# list all data in history
print(history.history.keys())
# Out:
# dict_keys(['loss', 'mse', 'val_loss', 'val_mse'])

# %%
# summarize history for accuracy
# plt.figure()
# plt.grid()
# plt.plot(history.history['accuracy'])
# plt.plot(history.history['val_accuracy'])
# plt.title('model accuracy')
# plt.ylabel('accuracy')
# plt.xlabel('epoch')
# plt.legend(['train', 'test'], loc='upper left')
# plt.tight_layout()
# plt.savefig('autoencoder_learning_curve_accuracy.png', dpi=300)
# plt.show()

# summarize history for loss
plt.figure()
plt.grid()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss - MSE')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Training', 'Validation'], loc='upper left')
plt.tight_layout()
plt.savefig('autoencoder_learning_curve_loss.png', dpi=300)
plt.show()

# %%
auto_encoder.encoder.save_weights("encoder_ckpt")
