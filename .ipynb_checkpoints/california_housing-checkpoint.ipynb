# %%
import math
import pandas as pd
import tensorflow as tf
import keras_tuner.tuners as kt
import matplotlib.pyplot as plt
from tensorflow.keras import Model
from tensorflow.keras import Sequential
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from tensorflow.keras.losses import MeanSquaredLogarithmicError
from sklearn.datasets import fetch_california_housing

# data in google colab
# TRAIN_DATA_PATH = '/content/sample_data/california_housing_train.csv'
# TEST_DATA_PATH = '/content/sample_data/california_housing_test.csv'


# train_data = pd.read_csv(TRAIN_DATA_PATH)
# test_data = pd.read_csv(TEST_DATA_PATH)

# %%
TARGET_NAME = 'median_house_value'

california_housing = fetch_california_housing(as_frame=True)
data = california_housing['data']
# target = california_housing['target']
data
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# 1        -122.22
# 2        -122.24
# 3        -122.25
# 4        -122.25
# ...          ...
# 20635    -121.09
# 20636    -121.21
# 20637    -121.22
# 20638    -121.32
# 20639    -121.24
#
# [20640 rows x 8 columns]

# %%
shuffled_df = data.sample(frac=1).reset_index(drop=True)
shuffled_df
# Out:
#         MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0       2.2969      47.0  4.284722   1.125000       754.0  5.236111     33.98
# 1       1.6302      32.0  3.182870   1.037037      1698.0  3.930556     34.02
# 2       4.1411      30.0  4.978998   0.972536      2008.0  3.243942     34.11
# 3      10.0914      52.0  7.546392   0.962199       668.0  2.295533     37.79
# 4       1.7083      29.0  2.898637   1.164395      3432.0  2.923339     34.10
# ...        ...       ...       ...        ...         ...       ...       ...
# 20635   5.1207      34.0  5.063939   0.984655       970.0  2.480818     37.53
# 20636   3.2841      15.0  5.478846   1.032692       878.0  1.688462     33.71
# 20637   2.2264      33.0  4.448936   0.995745      1053.0  2.240426     38.59
# 20638   3.3654      23.0  6.375000   1.335648       887.0  2.053241     39.31
# 20639   3.6540      38.0  4.936364   1.069091      2357.0  2.142727     32.75
#
#        Longitude
# 0        -118.25
# 1        -118.25
# 2        -117.88
# 3        -122.45
# 4        -118.30
# ...          ...
# 20635    -122.28
# 20636    -117.75
# 20637    -121.39
# 20638    -123.81
# 20639    -117.17
#
# [20640 rows x 8 columns]

# %%
split_pt = int(0.8*len(shuffled_df))

x_train = shuffled_df[:split_pt]
x_test = shuffled_df[split_pt:]

# %%
# x_train, y_train = train_data.drop(TARGET_NAME, axis=1), train_data[TARGET_NAME]
# x_test, y_test = test_data.drop(TARGET_NAME, axis=1), test_data[TARGET_NAME]
x_test
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 16512  5.4372      30.0  6.227848   1.020253      1277.0  3.232911     33.79
# 16513  6.2045      29.0  5.951923   1.043269      1217.0  2.925481     37.31
# 16514  2.5437      43.0  4.662614   1.167173      1231.0  3.741641     33.99
# 16515  5.2032      10.0  6.277064   1.033028      1689.0  3.099083     38.69
# 16516  3.1190      34.0  4.130890   1.047120      1041.0  5.450262     33.91
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  5.1207      34.0  5.063939   0.984655       970.0  2.480818     37.53
# 20636  3.2841      15.0  5.478846   1.032692       878.0  1.688462     33.71
# 20637  2.2264      33.0  4.448936   0.995745      1053.0  2.240426     38.59
# 20638  3.3654      23.0  6.375000   1.335648       887.0  2.053241     39.31
# 20639  3.6540      38.0  4.936364   1.069091      2357.0  2.142727     32.75
#
#        Longitude
# 16512    -118.01
# 16513    -122.04
# 16514    -118.30
# 16515    -120.95
# 16516    -118.23
# ...          ...
# 20635    -122.28
# 20636    -117.75
# 20637    -121.39
# 20638    -123.81
# 20639    -117.17
#
# [4128 rows x 8 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

def scale_datasets(x_train, x_test):
  """
  Standard Scale test and train data
  """
  standard_scaler = MinMaxScaler()
  x_train_scaled = pd.DataFrame(
      standard_scaler.fit_transform(x_train),
      columns=x_train.columns
  )
  x_test_scaled = pd.DataFrame(
      standard_scaler.transform(x_test),
      columns = x_test.columns
  )
  return x_train_scaled, x_test_scaled
  
x_train_scaled, x_test_scaled = scale_datasets(x_train, x_test)

# %%
class AutoEncoders(Model):

    def __init__(self, output_units):

        super().__init__()
        self.encoder = Sequential(
            [
              Dense(32, activation="relu"),
              Dense(16, activation="relu"),
              Dense(7, activation="relu")
            ]
        )

        self.decoder = Sequential(
            [
              Dense(16, activation="relu"),
              Dense(32, activation="relu"),
              Dense(output_units, activation="sigmoid")
            ]
        )

    def call(self, inputs):

        encoded = self.encoder(inputs)
        decoded = self.decoder(encoded)
        return decoded

auto_encoder = AutoEncoders(len(x_train_scaled.columns))

auto_encoder.compile(
    loss='mae',
    metrics=['mae'],
    optimizer='adam'
)

history = auto_encoder.fit(
    x_train_scaled, 
    x_train_scaled, 
    epochs=15, 
    batch_size=32, 
    validation_data=(x_test_scaled, x_test_scaled)
)
# Out:
# Epoch 1/15
# 516/516 [==============================] - 1s 1ms/step - loss: 0.0897 - mae: 0.0897 - val_loss: 0.0294 - val_mae: 0.0294
# Epoch 2/15
# 516/516 [==============================] - 1s 1ms/step - loss: 0.0196 - mae: 0.0196 - val_loss: 0.0162 - val_mae: 0.0162
# Epoch 3/15
# 516/516 [==============================] - 1s 983us/step - loss: 0.0154 - mae: 0.0154 - val_loss: 0.0149 - val_mae: 0.0149
# Epoch 4/15
# 516/516 [==============================] - 1s 1ms/step - loss: 0.0148 - mae: 0.0148 - val_loss: 0.0141 - val_mae: 0.0141
# Epoch 5/15
# 516/516 [==============================] - 1s 977us/step - loss: 0.0141 - mae: 0.0141 - val_loss: 0.0134 - val_mae: 0.0134
# Epoch 6/15
# 516/516 [==============================] - 1s 978us/step - loss: 0.0135 - mae: 0.0135 - val_loss: 0.0130 - val_mae: 0.0130
# Epoch 7/15
# 516/516 [==============================] - 1s 975us/step - loss: 0.0131 - mae: 0.0131 - val_loss: 0.0134 - val_mae: 0.0134
# Epoch 8/15
# 516/516 [==============================] - 1s 977us/step - loss: 0.0130 - mae: 0.0130 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 9/15
# 516/516 [==============================] - 1s 972us/step - loss: 0.0129 - mae: 0.0129 - val_loss: 0.0129 - val_mae: 0.0129
# Epoch 10/15
# 516/516 [==============================] - 1s 987us/step - loss: 0.0127 - mae: 0.0127 - val_loss: 0.0124 - val_mae: 0.0124
# Epoch 11/15
# 516/516 [==============================] - 1s 1ms/step - loss: 0.0127 - mae: 0.0127 - val_loss: 0.0124 - val_mae: 0.0124
# Epoch 12/15
# 516/516 [==============================] - 1s 985us/step - loss: 0.0126 - mae: 0.0126 - val_loss: 0.0123 - val_mae: 0.0123
# Epoch 13/15
# 516/516 [==============================] - 1s 979us/step - loss: 0.0125 - mae: 0.0125 - val_loss: 0.0123 - val_mae: 0.0123
# Epoch 14/15
# 516/516 [==============================] - 1s 968us/step - loss: 0.0124 - mae: 0.0124 - val_loss: 0.0123 - val_mae: 0.0123
# Epoch 15/15
# 516/516 [==============================] - 1s 981us/step - loss: 0.0122 - mae: 0.0122 - val_loss: 0.0127 - val_mae: 0.0127

# %%
encoder_layer = auto_encoder.get_layer('sequential_2')
reduced_df = pd.DataFrame(encoder_layer.predict(x_train_scaled))
reduced_df = reduced_df.add_prefix('feature_')
# Out:
# 516/516 [==============================] - 0s 519us/step

# %%
# list all data in history
print(history.history.keys())
# Out:
# dict_keys(['loss', 'mae', 'val_loss', 'val_mae'])

# %%
# summarize history for accuracy
plt.figure()
# plt.grid()
plt.plot(history.history['mae'])
plt.plot(history.history['val_mae'])
plt.title('model mae')
plt.ylabel('mae')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.tight_layout()
# plt.savefig(str_output_filename_prefix + 'autoencoder_learning_curve_accuracy.png', dpi=300)
plt.show()
# summarize history for loss
plt.figure()
plt.grid()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.tight_layout()
# plt.savefig(str_output_filename_prefix + 'autoencoder_learning_curve_loss.png', dpi=300)
# plt.show()
