# %%
import seaborn as sns
import pandas as pd

num_genes = 100

# %%
core = pd.read_csv('core_icd.csv')
core.rename(columns={'Gene ID':'Gene_ID'}, inplace=True)
# core = core[core['Gene_ID'].apply(lambda x: str(x).isdigit())]
# core = core[core.Gene_ID.astype(int).isin(dataset.Gene_ID.astype(int))]
# core = core[core['Gene_ID'].apply(lambda x: isinstance(x, int))]
core
# Out:
#      Gene_ID Gene Symbol  iCD-1 vs Ctl Fold change >= 1.5   \
# 0     405753      DUOXA2                            34.267
# 1       4314        MMP3                            21.431
# 2        366        AQP9                            21.243
# 3       3576         IL8                            18.578
# 4      50506       DUOX2                            15.849
# ...      ...         ...                               ...
# 1276  338094     FAM151A                            -9.422
# 1277    8029        CUBN                            -9.435
# 1278   64902       AGXT2                           -10.177
# 1279    9027        NAT8                           -10.575
# 1280     335       APOA1                           -10.787
#
#       Log FC (iCD-1 vs Ctl)  iCD-2 vs Ctl Fold change >= 1.5   \
# 0                     5.099                            51.931
# 1                     4.422                            29.681
# 2                     4.409                            32.809
# 3                     4.216                            27.838
# 4                     3.986                            19.216
# ...                     ...                               ...
# 1276                 -3.236                            -8.349
# 1277                 -3.238                            -6.882
# 1278                 -3.347                            -6.692
# 1279                 -3.403                            -6.818
# 1280                 -3.431                            -6.552
#
#       Log FC (iCD-2 vs Ctl )
# 0                      5.699
# 1                      4.891
# 2                      5.036
# 3                      4.799
# 4                      4.264
# ...                      ...
# 1276                  -3.062
# 1277                  -2.783
# 1278                  -2.742
# 1279                  -2.769
# 1280                  -2.712
#
# [1281 rows x 6 columns]

# %%
core = core.sort_values(["Log FC (iCD-1 vs Ctl)"], ascending=False)
core
# Out:
#      Gene_ID Gene Symbol  iCD-1 vs Ctl Fold change >= 1.5   \
# 0     405753      DUOXA2                            34.267
# 1       4314        MMP3                            21.431
# 2        366        AQP9                            21.243
# 3       3576         IL8                            18.578
# 4      50506       DUOX2                            15.849
# ...      ...         ...                               ...
# 1276  338094     FAM151A                            -9.422
# 1277    8029        CUBN                            -9.435
# 1278   64902       AGXT2                           -10.177
# 1279    9027        NAT8                           -10.575
# 1280     335       APOA1                           -10.787
#
#       Log FC (iCD-1 vs Ctl)  iCD-2 vs Ctl Fold change >= 1.5   \
# 0                     5.099                            51.931
# 1                     4.422                            29.681
# 2                     4.409                            32.809
# 3                     4.216                            27.838
# 4                     3.986                            19.216
# ...                     ...                               ...
# 1276                 -3.236                            -8.349
# 1277                 -3.238                            -6.882
# 1278                 -3.347                            -6.692
# 1279                 -3.403                            -6.818
# 1280                 -3.431                            -6.552
#
#       Log FC (iCD-2 vs Ctl )
# 0                      5.699
# 1                      4.891
# 2                      5.036
# 3                      4.799
# 4                      4.264
# ...                      ...
# 1276                  -3.062
# 1277                  -2.783
# 1278                  -2.742
# 1279                  -2.769
# 1280                  -2.712
#
# [1281 rows x 6 columns]

# %%
icd1 = pd.concat([core.head(num_genes), core.tail(num_genes)])

icd1
# Out:
#      Gene_ID Gene Symbol  iCD-1 vs Ctl Fold change >= 1.5   \
# 0     405753      DUOXA2                            34.267
# 1       4314        MMP3                            21.431
# 2        366        AQP9                            21.243
# 3       3576         IL8                            18.578
# 4      50506       DUOX2                            15.849
# ...      ...         ...                               ...
# 1276  338094     FAM151A                            -9.422
# 1277    8029        CUBN                            -9.435
# 1278   64902       AGXT2                           -10.177
# 1279    9027        NAT8                           -10.575
# 1280     335       APOA1                           -10.787
#
#       Log FC (iCD-1 vs Ctl)  iCD-2 vs Ctl Fold change >= 1.5   \
# 0                     5.099                            51.931
# 1                     4.422                            29.681
# 2                     4.409                            32.809
# 3                     4.216                            27.838
# 4                     3.986                            19.216
# ...                     ...                               ...
# 1276                 -3.236                            -8.349
# 1277                 -3.238                            -6.882
# 1278                 -3.347                            -6.692
# 1279                 -3.403                            -6.818
# 1280                 -3.431                            -6.552
#
#       Log FC (iCD-2 vs Ctl )
# 0                      5.699
# 1                      4.891
# 2                      5.036
# 3                      4.799
# 4                      4.264
# ...                      ...
# 1276                  -3.062
# 1277                  -2.783
# 1278                  -2.742
# 1279                  -2.769
# 1280                  -2.712
#
# [200 rows x 6 columns]

# %%
core = core.sort_values(["Log FC (iCD-2 vs Ctl )"], ascending=False)
core
# Out:
#      Gene_ID Gene Symbol  iCD-1 vs Ctl Fold change >= 1.5   \
# 0     405753      DUOXA2                            34.267
# 2        366        AQP9                            21.243
# 1       4314        MMP3                            21.431
# 3       3576         IL8                            18.578
# 10      3577       CXCR1                            12.230
# ...      ...         ...                               ...
# 1273    1271       CNTFR                            -8.546
# 1266  169693     C9orf71                            -6.858
# 1272    2538        G6PC                            -8.011
# 1275    9153     SLC28A2                            -9.219
# 1276  338094     FAM151A                            -9.422
#
#       Log FC (iCD-1 vs Ctl)  iCD-2 vs Ctl Fold change >= 1.5   \
# 0                     5.099                            51.931
# 2                     4.409                            32.809
# 1                     4.422                            29.681
# 3                     4.216                            27.838
# 10                    3.612                            19.625
# ...                     ...                               ...
# 1273                 -3.095                            -6.979
# 1266                 -2.778                            -7.636
# 1272                 -3.002                            -7.651
# 1275                 -3.205                            -8.322
# 1276                 -3.236                            -8.349
#
#       Log FC (iCD-2 vs Ctl )
# 0                      5.699
# 2                      5.036
# 1                      4.891
# 3                      4.799
# 10                     4.295
# ...                      ...
# 1273                  -2.803
# 1266                  -2.933
# 1272                  -2.936
# 1275                  -3.057
# 1276                  -3.062
#
# [1281 rows x 6 columns]

# %%
icd2 = pd.concat([core.head(num_genes), core.tail(num_genes)])

icd2
# Out:
#      Gene_ID Gene Symbol  iCD-1 vs Ctl Fold change >= 1.5   \
# 0     405753      DUOXA2                            34.267
# 2        366        AQP9                            21.243
# 1       4314        MMP3                            21.431
# 3       3576         IL8                            18.578
# 10      3577       CXCR1                            12.230
# ...      ...         ...                               ...
# 1273    1271       CNTFR                            -8.546
# 1266  169693     C9orf71                            -6.858
# 1272    2538        G6PC                            -8.011
# 1275    9153     SLC28A2                            -9.219
# 1276  338094     FAM151A                            -9.422
#
#       Log FC (iCD-1 vs Ctl)  iCD-2 vs Ctl Fold change >= 1.5   \
# 0                     5.099                            51.931
# 2                     4.409                            32.809
# 1                     4.422                            29.681
# 3                     4.216                            27.838
# 10                    3.612                            19.625
# ...                     ...                               ...
# 1273                 -3.095                            -6.979
# 1266                 -2.778                            -7.636
# 1272                 -3.002                            -7.651
# 1275                 -3.205                            -8.322
# 1276                 -3.236                            -8.349
#
#       Log FC (iCD-2 vs Ctl )
# 0                      5.699
# 2                      5.036
# 1                      4.891
# 3                      4.799
# 10                     4.295
# ...                      ...
# 1273                  -2.803
# 1266                  -2.933
# 1272                  -2.936
# 1275                  -3.057
# 1276                  -3.062
#
# [200 rows x 6 columns]

# %%
hundred = pd.concat([icd1, icd2])
hundred.shape
# Out:
# (400, 6)

# %%
hundred.Gene_ID
# Out:
# 0       405753
# 1         4314
# 2          366
# 3         3576
# 4        50506
#          ...
# 1273      1271
# 1266    169693
# 1272      2538
# 1275      9153
# 1276    338094
# Name: Gene_ID, Length: 400, dtype: object

# %%
dataset = pd.read_csv('risk.csv')
gene_symbol = dataset.pop("Gene Symbol")
dataset.rename(columns={'Gene ID':'Gene_ID'}, inplace=True)
# gene_id = dataset.pop("Gene ID")
dataset
# Out:
#          Gene_ID  CCFA_Risk_001  CCFA_Risk_002  CCFA_Risk_003  CCFA_Risk_004  \
# 0              1       -0.53931        1.31210      -0.083781       -0.86227
# 1              2        0.79561        1.12940       0.602470        0.81323
# 2              3       -0.20249       -0.20249      -0.202490       -0.20249
# 3              9        1.02630       -0.65959       1.291500        0.19540
# 4             10        0.24641       -7.72410      -0.542870        0.39032
# ...          ...            ...            ...            ...            ...
# 36367  100653021        0.00000        0.00000       0.000000        0.00000
# 36368  100653022        0.00000        0.00000       0.000000        0.00000
# 36369  100653023        0.00000        0.00000       0.000000        0.00000
# 36370  100653024        0.00000        0.00000       0.000000        0.00000
# 36371  100653025        0.00000        0.00000       0.000000        0.00000
#
#        CCFA_Risk_005  CCFA_Risk_006  CCFA_Risk_007  CCFA_Risk_008  \
# 0            0.74121        0.72868        0.79123       -0.44062
# 1            0.80724        0.47415        0.38337        0.57451
# 2           -0.20249        0.10892       -0.20249       -0.20249
# 3           -0.39078        1.09460       -0.21672        0.36204
# 4           -4.82710       -0.58034       -1.78130       -0.16412
# ...              ...            ...            ...            ...
# 36367        0.00000        0.00000        0.00000        0.00000
# 36368        0.00000        0.00000        0.00000        0.00000
# 36369        0.00000        0.00000        0.00000        0.00000
# 36370        0.00000        0.00000        0.00000        0.00000
# 36371        0.00000        0.00000        0.00000        0.00000
#
#        CCFA_Risk_009  ...  CCFA_Risk_089  CCFA_Risk_090  CCFA_Risk_117  \
# 0           0.427530  ...       -1.20180      -0.208140      -0.221770
# 1           0.053534  ...       -0.41766       0.233700       0.155220
# 2          -0.202490  ...        0.43514       1.932800       2.077500
# 3           0.618120  ...        0.16248       0.372190      -0.019795
# 4          -0.404860  ...        0.69774       0.008138       0.013065
# ...              ...  ...            ...            ...            ...
# 36367       0.000000  ...        0.00000       0.000000       0.000000
# 36368       0.000000  ...        0.00000       0.000000       0.000000
# 36369       0.000000  ...        0.00000       0.000000       0.000000
# 36370       0.000000  ...        0.00000       0.000000       0.000000
# 36371       0.000000  ...        0.00000       0.000000       0.000000
#
#        CCFA_Risk_118  CCFA_Risk_121  CCFA_Risk_180  CCFA_Risk_114  \
# 0           -1.67290      -0.002418       0.569290        0.81253
# 1           -0.24888      -0.049269      -0.048866       -0.16492
# 2           -0.20249       0.184890       2.437500       -0.20249
# 3            0.19675       0.392790       0.112410       -0.34924
# 4            0.70364      -0.229340      -0.216230        0.41874
# ...              ...            ...            ...            ...
# 36367        0.00000       0.000000       0.000000        0.00000
# 36368        0.00000       0.000000       0.000000        0.00000
# 36369        0.00000       0.000000       0.000000        0.00000
# 36370        0.00000       0.000000       0.000000        0.00000
# 36371        0.00000       0.000000       0.000000        0.00000
#
#        CCFA_Risk_139  CCFA_Risk_237  CCFA_Risk_257
# 0            0.61751       0.150020       0.039876
# 1            1.06890      -0.224290       0.232120
# 2            1.47860       0.089707      -0.202490
# 3           -0.30852       0.606460       0.173880
# 4           -2.34260       0.000504      -0.296990
# ...              ...            ...            ...
# 36367        0.00000       0.000000       0.000000
# 36368        0.00000       0.000000       0.000000
# 36369        0.00000       0.000000       0.000000
# 36370        0.00000       0.000000       0.000000
# 36371        0.00000       0.000000       0.000000
#
# [36372 rows x 323 columns]

# %%
# select_all = dataset[dataset.Gene_ID.astype(str).isin(hundred.Gene_ID.astype(str))]

# %%
select_hundred = dataset[dataset.Gene_ID.astype(str).isin(hundred.Gene_ID.astype(str))]
# select_hundred.pop("Gene_ID")
select_hundred = select_hundred.set_index("Gene_ID")
# select_hundred = select_hundred[:-1]

# %%
select_hundred
# Out:
#            CCFA_Risk_001  CCFA_Risk_002  CCFA_Risk_003  CCFA_Risk_004  \
# Gene_ID
# 13              -0.88125        -8.3859        -3.4765       0.476000
# 116              1.77820         2.9376         3.0778       1.272300
# 335             -3.04650        -9.3617        -2.6363       0.934930
# 337             -0.91813        -7.1696        -2.6486       0.198870
# 338             -1.31280        -7.4158        -2.5412       1.910800
# ...                  ...            ...            ...            ...
# 100133023        3.58330         5.5289         4.2278       0.146220
# 100506115        3.57040         6.7679         5.0613      -0.964060
# 100507203       -1.89880        -7.9398        -1.8861      -0.008109
# 100507500       -2.28470        -5.7449        -3.9397       0.746300
# 100652986        1.65450         2.4724         2.5014       0.153220
#
#            CCFA_Risk_005  CCFA_Risk_006  CCFA_Risk_007  CCFA_Risk_008  \
# Gene_ID
# 13               -6.8609        -3.7573        -4.7448      -0.044202
# 116               3.2305         4.0869         3.5568      -0.640360
# 335              -6.4784        -5.8715        -9.4177      -0.653090
# 337              -7.4818        -3.0414        -7.5605      -0.947140
# 338              -7.0656        -3.7296        -6.8377       0.335400
# ...                  ...            ...            ...            ...
# 100133023         3.9361         4.0024         3.0066       1.507800
# 100506115         5.4606         4.0849         4.4060      -0.111190
# 100507203        -6.6277        -2.6742        -5.3596      -0.701730
# 100507500        -5.8906        -3.1773        -6.3929      -0.063170
# 100652986         3.1658         2.9514         1.2398       0.532640
#
#            CCFA_Risk_009  CCFA_Risk_012  ...  CCFA_Risk_089  CCFA_Risk_090  \
# Gene_ID                                  ...
# 13               -2.5065       0.006241  ...        1.16230       0.199200
# 116               4.5061       3.123200  ...        2.32900      -2.952500
# 335              -4.2686      -0.835050  ...        0.74486       0.200140
# 337              -1.6623      -0.893450  ...        0.54624       0.532340
# 338              -3.1109      -0.016976  ...        1.02530       0.417150
# ...                  ...            ...  ...            ...            ...
# 100133023         3.2543       1.573600  ...       -1.77460      -0.029632
# 100506115         4.0273       0.609730  ...       -1.10140       0.770950
# 100507203        -1.4822       0.000851  ...        0.42567       0.121920
# 100507500        -3.0324      -0.107230  ...        0.49052       0.043785
# 100652986         2.5336       0.320740  ...       -1.59780      -1.037500
#
#            CCFA_Risk_117  CCFA_Risk_118  CCFA_Risk_121  CCFA_Risk_180  \
# Gene_ID
# 13              0.239030        1.36150      -0.934720       -0.24844
# 116             0.703410       -0.86453      -1.008700       -0.63437
# 335            -0.159320        1.05160      -1.207500       -1.06850
# 337            -0.298980        0.26538      -0.071699       -1.20620
# 338             0.146180        1.01690       0.075990       -0.44267
# ...                  ...            ...            ...            ...
# 100133023      -0.629990       -2.03420       0.935630        1.02880
# 100506115       0.969550        0.98079       2.039000       -1.10140
# 100507203      -0.016418        0.82466      -0.071756       -1.14600
# 100507500      -0.068741        0.94570      -0.277030       -1.19200
# 100652986      -0.784310       -0.94004      -0.047304        0.80473
#
#            CCFA_Risk_114  CCFA_Risk_139  CCFA_Risk_237  CCFA_Risk_257
# Gene_ID
# 13              -0.37507        -5.2289      -0.680680        -1.4899
# 116             -0.77409         2.4073       2.424200         1.9201
# 335              1.60890        -7.4559       0.396090        -2.9453
# 337              0.78129        -6.2972       0.225200        -1.9198
# 338             -0.37282        -5.4805      -0.043606        -2.8993
# ...                  ...            ...            ...            ...
# 100133023       -2.48970         4.1647       1.569400         3.9515
# 100506115        4.28490         5.3863       2.891300         4.5873
# 100507203        0.57241        -5.0405      -0.206750        -1.6078
# 100507500        1.50180        -6.3929      -0.181550        -1.0268
# 100652986       -1.62460         3.1130       1.478600         4.1414
#
# [233 rows x 322 columns]

# %%
select_hundred.describe()
# Out:
#        CCFA_Risk_001  CCFA_Risk_002  CCFA_Risk_003  CCFA_Risk_004  \
# count     101.000000     101.000000     101.000000     101.000000
# mean        0.250647      -0.850753       1.005252      -0.222146
# std         3.913759       7.036709       5.283470       1.435231
# min        -6.580700      -9.758000      -6.531400      -5.835900
# 25%        -3.378900      -7.334300      -3.994400      -0.665850
# 50%         0.000000      -2.864200      -2.169100       0.137200
# 75%         3.570400       7.059800       6.191100       0.675220
# max         7.623300      10.885300       8.701100       2.037900
#
#        CCFA_Risk_005  CCFA_Risk_006  CCFA_Risk_007  CCFA_Risk_008  \
# count     101.000000     101.000000     101.000000     101.000000
# mean       -0.299264       0.161181      -1.237255      -0.101097
# std         6.375803       4.927270       5.081129       1.373026
# min        -9.148200      -7.632200      -9.509100      -5.738000
# 25%        -6.531400      -4.379700      -5.883400      -0.625740
# 50%        -1.570800      -0.694450      -2.964100      -0.046010
# 75%         6.346200       5.019900       3.634700       0.343250
# max        10.076100       8.476300       6.956900       6.284800
#
#        CCFA_Risk_009  CCFA_Risk_012  ...  CCFA_Risk_089  CCFA_Risk_090  \
# count     101.000000     101.000000  ...     101.000000     101.000000
# mean        0.301300       0.256763  ...      -0.220522       0.514624
# std         4.436923       1.521801  ...       1.252791       0.892549
# min        -7.708600      -5.277600  ...      -3.993500      -1.074800
# 25%        -3.606800      -0.351070  ...      -0.943720      -0.083496
# 50%        -1.318700       0.108940  ...       0.191610       0.332230
# 75%         4.307300       0.861950  ...       0.653150       0.922570
# max        10.346600       5.072600  ...       2.110600       2.898600
#
#        CCFA_Risk_117  CCFA_Risk_118  CCFA_Risk_121  CCFA_Risk_180  \
# count     101.000000     101.000000     101.000000     101.000000
# mean        0.230410      -0.229187       0.687183      -0.213238
# std         0.808554       1.477520       1.867734       1.128542
# min        -2.062100      -4.333800      -3.963600      -2.917300
# 25%        -0.078279      -1.487000      -0.761610      -1.066800
# 50%         0.211780       0.013641       0.241210      -0.329040
# 75%         0.553560       0.980790       2.090200       0.672660
# max         2.354200       2.125900       4.953400       2.708600
#
#        CCFA_Risk_114  CCFA_Risk_139  CCFA_Risk_237  CCFA_Risk_257
# count     101.000000     101.000000     101.000000     101.000000
# mean        1.559855       0.349942       0.988490       1.361431
# std         2.344301       6.441364       2.599492       4.335106
# min        -3.472900      -7.702300      -5.738000      -5.094500
# 25%        -0.023618      -5.990900      -0.937210      -2.503200
# 50%         1.224800      -2.188800       0.396090      -0.914340
# 75%         3.078300       6.734800       3.006500       5.460900
# max         7.926300      10.961900       6.937200       8.431700
#
# [8 rows x 322 columns]

# %%
sns.clustermap(select_hundred)
# Out:
# C:\Users\shard\anaconda3\lib\site-packages\seaborn\matrix.py:654: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
select_hundred.to_csv('hundred_patients.csv')
