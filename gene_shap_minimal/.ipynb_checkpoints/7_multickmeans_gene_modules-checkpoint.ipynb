# %%
from pyckmeans import MultiCKMeans
import sklearn.datasets
import math
import pandas as pd
# import tensorflow as tf
# # import keras_tuner.tuners as kt
import matplotlib.pyplot as plt
# import keras
# from tensorflow.keras import Model
# from tensorflow.keras import Sequential
# from sklearn.preprocessing import StandardScaler
# from tensorflow.keras.layers import Dense, Dropout
# from sklearn.model_selection import train_test_split
# from tensorflow.keras.losses import MeanSquaredLogarithmicError
import numpy as np
import pickle
# np.random.seed(0)
# from tensorflow.keras import Input
# from tensorflow.keras.layers import Conv1D, Conv2D, LeakyReLU, MaxPool1D, AveragePooling1D, UpSampling1D, Flatten, Dense, Reshape, BatchNormalization
# # https://towardsdatascience.com/improve-your-model-performance-with-auto-encoders-d4ee543b4154
# from tensorflow.keras import initializers
# from keras.wrappers.scikit_learn import KerasRegressor
# from sklearn.model_selection import GridSearchCV
# from scipy.stats import multivariate_normal
# from keras.optimizers import Adam, SGD, Adadelta

# %%
x_train_scaled = pd.read_csv('../data/260_sample_train_scaled.csv').set_index("Patient_ID")
x_train_scaled
# Out:
#                  AADAC     APOA1     APOA4      APOB     APOC3      AQP9  \
# Patient_ID
# 55_control    0.702813  0.799052  0.719665  0.729547  0.794953  0.256451
# 168_CD_plain  0.751408  0.603707  0.622768  0.627712  0.606860  0.520576
# 72_control    0.786508  0.755331  0.739605  0.756170  0.819875  0.391132
# 120_control   0.707491  0.662993  0.648072  0.764621  0.654276  0.633929
# 258_CD_plain  0.701039  0.662511  0.707208  0.834562  0.670160  0.410612
# ...                ...       ...       ...       ...       ...       ...
# 15_CD_plain   0.382762  0.384030  0.377332  0.360165  0.300915  0.340090
# 182_CD_plain  0.679910  0.584723  0.722426  0.643867  0.740014  0.650358
# 164_CD_plain  0.754656  0.556562  0.694062  0.748334  0.535534  0.133869
# 53_CD_plain   0.591140  0.585802  0.750282  0.753309  0.603372  0.469634
# 97_CD_plain   0.817125  0.782223  0.854442  0.867360  0.793421  0.726438
#
#                     C6   CEACAM7    CHI3L1     ABCC2  ...     HDLBP     PIAS4  \
# Patient_ID                                            ...
# 55_control    1.000000  0.363133  0.374212  0.611161  ...  0.308725  0.235825
# 168_CD_plain  0.311962  0.251356  0.553554  0.441131  ...  0.000000  0.000000
# 72_control    0.648401  0.134017  0.200420  0.679453  ...  0.491401  0.279122
# 120_control   0.579519  0.248934  0.759250  0.755407  ...  0.604918  0.598850
# 258_CD_plain  0.370517  0.244987  0.445387  0.798000  ...  0.470835  0.670696
# ...                ...       ...       ...       ...  ...       ...       ...
# 15_CD_plain   0.077348  0.890965  0.261140  0.205779  ...  0.669319  0.770253
# 182_CD_plain  0.468650  0.295686  0.649939  0.609862  ...  0.747236  0.742399
# 164_CD_plain  0.319071  0.154562  0.440487  0.824013  ...  0.422981  0.769213
# 53_CD_plain   0.213239  0.348800  0.485094  0.722492  ...  0.618164  0.707833
# 97_CD_plain   0.246396  0.228774  0.611752  0.699944  ...  0.696152  0.625429
#
#                  ADH1B  LOC100507531    FAM83A      NXF4    RNF125      DARS  \
# Patient_ID
# 55_control    0.566757      0.982782  0.707526  1.000000  0.410887  0.671068
# 168_CD_plain  0.861588      0.000000  0.640911  0.020238  0.220356  0.632252
# 72_control    0.555258      0.000000  0.392175  0.000000  0.116289  0.000000
# 120_control   0.621841      0.000000  0.519941  0.000000  0.342185  0.416527
# 258_CD_plain  0.555250      0.000000  0.390923  0.000000  0.498504  0.449224
# ...                ...           ...       ...       ...       ...       ...
# 15_CD_plain   0.702931      0.000000  0.451846  0.000000  0.319644  0.549587
# 182_CD_plain  0.730485      0.000000  0.680460  0.000000  0.280413  0.529434
# 164_CD_plain  0.625325      0.000000  0.374319  0.000000  0.396084  0.590976
# 53_CD_plain   0.842618      0.000000  0.441203  0.000000  0.355054  0.430549
# 97_CD_plain   0.497239      0.000000  0.418343  0.000000  0.346990  0.629297
#
#                  DNAI1    MBTPS1
# Patient_ID
# 55_control    1.000000  0.438527
# 168_CD_plain  0.000000  0.488578
# 72_control    0.260194  0.531400
# 120_control   0.000000  0.545708
# 258_CD_plain  0.000000  0.689242
# ...                ...       ...
# 15_CD_plain   0.000000  0.935108
# 182_CD_plain  0.000000  0.606330
# 164_CD_plain  0.238307  0.753111
# 53_CD_plain   0.000000  0.706947
# 97_CD_plain   0.000000  0.634364
#
# [182 rows x 220 columns]

# %%
x_test_scaled = pd.read_csv('../data/260_sample_test_scaled.csv').set_index("Patient_ID")
x_test_scaled
# Out:
#                       AADAC     APOA1     APOA4      APOB     APOC3      AQP9  \
# Patient_ID
# 253_CD_plain       0.869185  0.841880  0.930171  0.886737  0.835678  0.297964
# 105_CD_plain       0.853562  0.933532  0.942213  0.794578  0.890482  0.206529
# 2_CD_plain         0.165531  0.141475  0.263684  0.198091  0.160503  0.888878
# 184_CD_plain       0.717121  0.660314  0.769417  0.752737  0.694874  0.514735
# 312_CD_plain       0.730072  0.722909  0.713076  0.743545  0.679258  0.308459
# ...                     ...       ...       ...       ...       ...       ...
# 107_CD_plain       0.736123  0.658232  0.772323  0.685637  0.658755  0.250970
# 279_CD_plain       0.220614  0.202090  0.182810  0.113245  0.105744  0.699851
# 179_CD_plain       0.724476  0.726774  0.766943  0.776284  0.690339  0.380637
# 70_CD_deep_ulcer   0.488321  0.495439  0.574906  0.491337  0.540073  0.525943
# 256_CD_deep_ulcer  0.609459  0.598912  0.682050  0.765806  0.648350  0.450384
#
#                          C6   CEACAM7    CHI3L1     ABCC2  ...     HDLBP  \
# Patient_ID                                                 ...
# 253_CD_plain       0.668498  0.266670  0.278122  0.933520  ...  0.775985
# 105_CD_plain       0.298987  0.350745  0.495663  0.849038  ...  0.582213
# 2_CD_plain         0.000000  0.134461  0.989132  0.202203  ...  0.907365
# 184_CD_plain       0.692365  0.271127  0.650742  0.694599  ...  0.648501
# 312_CD_plain       0.399235  0.129019  0.597529  0.720390  ...  0.493294
# ...                     ...       ...       ...       ...  ...       ...
# 107_CD_plain       0.247307  0.422075  0.555944  0.603675  ...  0.550182
# 279_CD_plain       0.000000  0.908485  0.688912  0.178259  ...  0.819116
# 179_CD_plain       0.440449  0.318944  0.558600  0.738787  ...  0.417027
# 70_CD_deep_ulcer   0.397648  0.414520  0.709700  0.389618  ...  0.518145
# 256_CD_deep_ulcer  0.000000  0.377102  0.444380  0.667302  ...  0.710513
#
#                       PIAS4     ADH1B  LOC100507531    FAM83A  NXF4    RNF125  \
# Patient_ID
# 253_CD_plain       0.973492  0.472825           0.0  0.269797   0.0  0.539781
# 105_CD_plain       0.531660  0.540145           0.0  0.322049   0.0  0.303573
# 2_CD_plain         0.736128 -0.336653           0.0 -0.069528   0.0  0.176989
# 184_CD_plain       0.789699  0.836996           0.0  0.285660   0.0  0.320280
# 312_CD_plain       0.566990  0.807264           0.0  0.471971   0.0  0.462733
# ...                     ...       ...           ...       ...   ...       ...
# 107_CD_plain       0.719685  0.701615           0.0  0.225656   0.0  0.295914
# 279_CD_plain       0.689739  0.213157           0.0  0.969447   0.0  0.134090
# 179_CD_plain       0.734039  0.683655           0.0  0.369566   0.0  0.405814
# 70_CD_deep_ulcer   0.592796  0.889984           0.0  0.437243   0.0  0.216913
# 256_CD_deep_ulcer  0.667492  0.601592           0.0  0.653043   0.0  0.409098
#
#                        DARS     DNAI1    MBTPS1
# Patient_ID
# 253_CD_plain       0.290165  0.000000  0.722611
# 105_CD_plain       0.133159  0.000000  0.537012
# 2_CD_plain         0.766373  0.000000  1.094845
# 184_CD_plain       0.488913  0.000000  0.674738
# 312_CD_plain       0.508932  0.000000  0.693707
# ...                     ...       ...       ...
# 107_CD_plain       0.701896  0.000000  0.709542
# 279_CD_plain       0.710444  0.000000  0.846294
# 179_CD_plain       0.575430  0.000000  0.653918
# 70_CD_deep_ulcer   0.514257  0.000000  0.621144
# 256_CD_deep_ulcer  0.449809  0.152556  0.599646
#
# [78 rows x 220 columns]

# %%
full_ds = pd.concat([x_train_scaled, x_test_scaled])
full_ds
# Out:
#                       AADAC     APOA1     APOA4      APOB     APOC3      AQP9  \
# Patient_ID
# 55_control         0.702813  0.799052  0.719665  0.729547  0.794953  0.256451
# 168_CD_plain       0.751408  0.603707  0.622768  0.627712  0.606860  0.520576
# 72_control         0.786508  0.755331  0.739605  0.756170  0.819875  0.391132
# 120_control        0.707491  0.662993  0.648072  0.764621  0.654276  0.633929
# 258_CD_plain       0.701039  0.662511  0.707208  0.834562  0.670160  0.410612
# ...                     ...       ...       ...       ...       ...       ...
# 107_CD_plain       0.736123  0.658232  0.772323  0.685637  0.658755  0.250970
# 279_CD_plain       0.220614  0.202090  0.182810  0.113245  0.105744  0.699851
# 179_CD_plain       0.724476  0.726774  0.766943  0.776284  0.690339  0.380637
# 70_CD_deep_ulcer   0.488321  0.495439  0.574906  0.491337  0.540073  0.525943
# 256_CD_deep_ulcer  0.609459  0.598912  0.682050  0.765806  0.648350  0.450384
#
#                          C6   CEACAM7    CHI3L1     ABCC2  ...     HDLBP  \
# Patient_ID                                                 ...
# 55_control         1.000000  0.363133  0.374212  0.611161  ...  0.308725
# 168_CD_plain       0.311962  0.251356  0.553554  0.441131  ...  0.000000
# 72_control         0.648401  0.134017  0.200420  0.679453  ...  0.491401
# 120_control        0.579519  0.248934  0.759250  0.755407  ...  0.604918
# 258_CD_plain       0.370517  0.244987  0.445387  0.798000  ...  0.470835
# ...                     ...       ...       ...       ...  ...       ...
# 107_CD_plain       0.247307  0.422075  0.555944  0.603675  ...  0.550182
# 279_CD_plain       0.000000  0.908485  0.688912  0.178259  ...  0.819116
# 179_CD_plain       0.440449  0.318944  0.558600  0.738787  ...  0.417027
# 70_CD_deep_ulcer   0.397648  0.414520  0.709700  0.389618  ...  0.518145
# 256_CD_deep_ulcer  0.000000  0.377102  0.444380  0.667302  ...  0.710513
#
#                       PIAS4     ADH1B  LOC100507531    FAM83A      NXF4  \
# Patient_ID
# 55_control         0.235825  0.566757      0.982782  0.707526  1.000000
# 168_CD_plain       0.000000  0.861588      0.000000  0.640911  0.020238
# 72_control         0.279122  0.555258      0.000000  0.392175  0.000000
# 120_control        0.598850  0.621841      0.000000  0.519941  0.000000
# 258_CD_plain       0.670696  0.555250      0.000000  0.390923  0.000000
# ...                     ...       ...           ...       ...       ...
# 107_CD_plain       0.719685  0.701615      0.000000  0.225656  0.000000
# 279_CD_plain       0.689739  0.213157      0.000000  0.969447  0.000000
# 179_CD_plain       0.734039  0.683655      0.000000  0.369566  0.000000
# 70_CD_deep_ulcer   0.592796  0.889984      0.000000  0.437243  0.000000
# 256_CD_deep_ulcer  0.667492  0.601592      0.000000  0.653043  0.000000
#
#                      RNF125      DARS     DNAI1    MBTPS1
# Patient_ID
# 55_control         0.410887  0.671068  1.000000  0.438527
# 168_CD_plain       0.220356  0.632252  0.000000  0.488578
# 72_control         0.116289  0.000000  0.260194  0.531400
# 120_control        0.342185  0.416527  0.000000  0.545708
# 258_CD_plain       0.498504  0.449224  0.000000  0.689242
# ...                     ...       ...       ...       ...
# 107_CD_plain       0.295914  0.701896  0.000000  0.709542
# 279_CD_plain       0.134090  0.710444  0.000000  0.846294
# 179_CD_plain       0.405814  0.575430  0.000000  0.653918
# 70_CD_deep_ulcer   0.216913  0.514257  0.000000  0.621144
# 256_CD_deep_ulcer  0.409098  0.449809  0.152556  0.599646
#
# [260 rows x 220 columns]

# %%
# gene_df_shap = pd.DataFrame(shap_values[2], index=x_test_scaled.index, columns = x_test_scaled.columns)
df_cd_deep = full_ds[full_ds.index.str.endswith('_CD_deep_ulcer')]
df_cd_plain = full_ds[full_ds.index.str.endswith('_CD_plain')]
df_control = full_ds[full_ds.index.str.endswith('_control')]
df_cd_deep
# Out:
#                       AADAC     APOA1     APOA4      APOB     APOC3      AQP9  \
# Patient_ID
# 254_CD_deep_ulcer  0.688952  0.790972  0.730387  0.698611  0.814798  0.539765
# 216_CD_deep_ulcer  0.392511  0.306222  0.540222  0.462697  0.430877  0.751154
# 263_CD_deep_ulcer  0.269897  0.214387  0.187335  0.158953  0.180396  0.856687
# 95_CD_deep_ulcer   0.322076  0.317311  0.295913  0.189476  0.222371  0.635286
# 223_CD_deep_ulcer  0.697044  0.615143  0.670016  0.731387  0.602704  0.613085
# ...                     ...       ...       ...       ...       ...       ...
# 145_CD_deep_ulcer  0.580654  0.316558  0.463705  0.469550  0.382367  0.548972
# 143_CD_deep_ulcer  0.524637  0.358230  0.463575  0.519032  0.484028  0.641028
# 165_CD_deep_ulcer  0.631350  0.589925  0.672493  0.684450  0.603240  0.642262
# 70_CD_deep_ulcer   0.488321  0.495439  0.574906  0.491337  0.540073  0.525943
# 256_CD_deep_ulcer  0.609459  0.598912  0.682050  0.765806  0.648350  0.450384
#
#                          C6   CEACAM7    CHI3L1     ABCC2  ...     HDLBP  \
# Patient_ID                                                 ...
# 254_CD_deep_ulcer  0.476091  0.531103  0.643682  0.557025  ...  0.896314
# 216_CD_deep_ulcer  0.073092  0.495681  0.926051  0.333960  ...  0.628174
# 263_CD_deep_ulcer  0.000000  0.274659  0.916233  0.329184  ...  0.676782
# 95_CD_deep_ulcer   0.186784  0.809517  0.583656  0.224686  ...  0.412036
# 223_CD_deep_ulcer  0.000000  0.321284  0.676704  0.632284  ...  0.760476
# ...                     ...       ...       ...       ...  ...       ...
# 145_CD_deep_ulcer  0.146997  0.372269  0.697253  0.267339  ...  0.716515
# 143_CD_deep_ulcer  0.171927  0.547367  0.820735  0.317961  ...  0.594630
# 165_CD_deep_ulcer  0.547043  0.142334  0.726706  0.604319  ...  0.650324
# 70_CD_deep_ulcer   0.397648  0.414520  0.709700  0.389618  ...  0.518145
# 256_CD_deep_ulcer  0.000000  0.377102  0.444380  0.667302  ...  0.710513
#
#                       PIAS4     ADH1B  LOC100507531    FAM83A  NXF4    RNF125  \
# Patient_ID
# 254_CD_deep_ulcer  0.606656  0.701423      0.000000  0.463325   0.0  0.187535
# 216_CD_deep_ulcer  0.730207  0.621085      0.000000  0.784235   0.0  0.166508
# 263_CD_deep_ulcer  0.758230  0.363315      0.000000  0.318012   0.0  0.138248
# 95_CD_deep_ulcer   0.536312  0.782205      0.957778  0.625245   0.0  0.170622
# 223_CD_deep_ulcer  0.814575  0.638118      0.000000  0.678263   0.0  0.369031
# ...                     ...       ...           ...       ...   ...       ...
# 145_CD_deep_ulcer  0.698486  0.623608      0.000000  0.718448   0.0  0.143467
# 143_CD_deep_ulcer  0.596784  0.646983      0.000000  0.733494   0.0  0.134436
# 165_CD_deep_ulcer  0.791050  0.562159      0.000000  0.595583   0.0  0.327792
# 70_CD_deep_ulcer   0.592796  0.889984      0.000000  0.437243   0.0  0.216913
# 256_CD_deep_ulcer  0.667492  0.601592      0.000000  0.653043   0.0  0.409098
#
#                        DARS     DNAI1    MBTPS1
# Patient_ID
# 254_CD_deep_ulcer  0.359715  0.000000  0.121054
# 216_CD_deep_ulcer  0.622527  0.000000  0.750853
# 263_CD_deep_ulcer  0.519956  0.000000  1.000000
# 95_CD_deep_ulcer   0.527916  0.000000  0.722416
# 223_CD_deep_ulcer  0.500526  0.000000  0.635721
# ...                     ...       ...       ...
# 145_CD_deep_ulcer  0.348890  0.046075  0.686094
# 143_CD_deep_ulcer  0.498464  0.330059  0.639803
# 165_CD_deep_ulcer  0.455081  0.105957  0.623358
# 70_CD_deep_ulcer   0.514257  0.000000  0.621144
# 256_CD_deep_ulcer  0.449809  0.152556  0.599646
#
# [76 rows x 220 columns]

# %%
with open("../data/models/shap/new_ind_all_400", "rb") as fp:   # Unpickling
    shap_values = pickle.load(fp)

# %%
shap_values = shap_values[0]

# %%
gene_df_shap = pd.DataFrame(shap_values[2], index=x_test_scaled.index, columns = x_test_scaled.columns)
df_train_cd_deep_shap = gene_df_shap[gene_df_shap.index.str.endswith('_CD_deep_ulcer')]
df_train_cd_plain_shap = gene_df_shap[gene_df_shap.index.str.endswith('_CD_plain')]
df_train_control_shap = gene_df_shap[gene_df_shap.index.str.endswith('_control')]
df_train_cd_deep_shap.describe()
# Out:
#            AADAC      APOA1      APOA4        APOB      APOC3       AQP9  \
# count  24.000000  24.000000  24.000000   24.000000  24.000000  24.000000
# mean   -5.496363  -0.789341  -0.037038    4.653398  -1.031784   3.002884
# std    11.652575  16.642071  16.198998   29.010648  13.705945   8.102881
# min   -34.890732 -47.298582 -24.597463 -101.019448 -35.051066 -10.218768
# 25%   -11.931632  -2.419380  -9.649359    0.000000  -5.279232  -0.281946
# 50%    -1.562356   0.000000  -0.495575    4.242113   0.050643   0.000000
# 75%     2.445564   4.666901   3.916130    9.345444   2.537448   4.934474
# max    13.083386  35.764123  57.741192   85.675325  42.587423  23.227178
#
#               C6    CEACAM7     CHI3L1      ABCC2  ...       HDLBP      PIAS4  \
# count  24.000000  24.000000  24.000000  24.000000  ...   24.000000  24.000000
# mean    1.856534  -0.415168   1.538201  -2.175980  ...    7.510481  -2.141452
# std    23.801516  17.052223  12.571107  11.603018  ...   32.024610   8.621977
# min   -38.636531 -32.654574 -19.726747 -26.788123  ...  -14.199077 -24.635162
# 25%    -3.619996  -7.197033  -2.705871  -4.321975  ...   -2.448436  -7.108680
# 50%     0.000000  -0.642456   0.000000   0.000000  ...    0.152989  -0.355631
# 75%     4.407609   3.657562   0.000000   2.169466  ...    5.510180   0.922345
# max    89.489328  67.243137  52.652770  25.960817  ...  151.140856  13.037966
#
#            ADH1B  LOC100507531     FAM83A       NXF4     RNF125       DARS  \
# count  24.000000     24.000000  24.000000  24.000000  24.000000  24.000000
# mean    1.555291     -0.745504  -3.534669   1.764898   3.593158   0.088958
# std    10.603262     12.583011   9.131770   8.491458  21.356245  16.491311
# min   -28.797143    -26.358982 -27.311825  -7.673958 -49.988338 -42.729326
# 25%    -3.880024     -4.190777  -7.737511  -3.928331  -3.129121  -4.007470
# 50%     2.521795      0.000000   0.000000   0.551885   0.000000   0.000000
# 75%     7.224177      2.718560   2.010179   3.311928   7.496647   7.237860
# max    20.294425     42.876414   7.929053  30.051868  72.389340  42.873870
#
#            DNAI1     MBTPS1
# count  24.000000  24.000000
# mean    1.764544   8.503077
# std    17.661747  22.801953
# min   -35.833474 -25.912554
# 25%    -5.200349  -0.409944
# 50%    -0.074214   0.715804
# 75%     4.381183  15.601786
# max    58.721092  96.835082
#
# [8 rows x 220 columns]

# %% [markdown]
# # CD Deep Ulcer

# %% [markdown]
# # Pre-processing dataset

# %%
gene_shap_means = df_train_cd_deep_shap.describe().loc["mean"].values
gene_shap_means_abs = np.abs(gene_shap_means)

# %%
full_exp_df = full_ds.copy()
full_exp_df
# Out:
#                       AADAC     APOA1     APOA4      APOB     APOC3      AQP9  \
# Patient_ID
# 55_control         0.702813  0.799052  0.719665  0.729547  0.794953  0.256451
# 168_CD_plain       0.751408  0.603707  0.622768  0.627712  0.606860  0.520576
# 72_control         0.786508  0.755331  0.739605  0.756170  0.819875  0.391132
# 120_control        0.707491  0.662993  0.648072  0.764621  0.654276  0.633929
# 258_CD_plain       0.701039  0.662511  0.707208  0.834562  0.670160  0.410612
# ...                     ...       ...       ...       ...       ...       ...
# 107_CD_plain       0.736123  0.658232  0.772323  0.685637  0.658755  0.250970
# 279_CD_plain       0.220614  0.202090  0.182810  0.113245  0.105744  0.699851
# 179_CD_plain       0.724476  0.726774  0.766943  0.776284  0.690339  0.380637
# 70_CD_deep_ulcer   0.488321  0.495439  0.574906  0.491337  0.540073  0.525943
# 256_CD_deep_ulcer  0.609459  0.598912  0.682050  0.765806  0.648350  0.450384
#
#                          C6   CEACAM7    CHI3L1     ABCC2  ...     HDLBP  \
# Patient_ID                                                 ...
# 55_control         1.000000  0.363133  0.374212  0.611161  ...  0.308725
# 168_CD_plain       0.311962  0.251356  0.553554  0.441131  ...  0.000000
# 72_control         0.648401  0.134017  0.200420  0.679453  ...  0.491401
# 120_control        0.579519  0.248934  0.759250  0.755407  ...  0.604918
# 258_CD_plain       0.370517  0.244987  0.445387  0.798000  ...  0.470835
# ...                     ...       ...       ...       ...  ...       ...
# 107_CD_plain       0.247307  0.422075  0.555944  0.603675  ...  0.550182
# 279_CD_plain       0.000000  0.908485  0.688912  0.178259  ...  0.819116
# 179_CD_plain       0.440449  0.318944  0.558600  0.738787  ...  0.417027
# 70_CD_deep_ulcer   0.397648  0.414520  0.709700  0.389618  ...  0.518145
# 256_CD_deep_ulcer  0.000000  0.377102  0.444380  0.667302  ...  0.710513
#
#                       PIAS4     ADH1B  LOC100507531    FAM83A      NXF4  \
# Patient_ID
# 55_control         0.235825  0.566757      0.982782  0.707526  1.000000
# 168_CD_plain       0.000000  0.861588      0.000000  0.640911  0.020238
# 72_control         0.279122  0.555258      0.000000  0.392175  0.000000
# 120_control        0.598850  0.621841      0.000000  0.519941  0.000000
# 258_CD_plain       0.670696  0.555250      0.000000  0.390923  0.000000
# ...                     ...       ...           ...       ...       ...
# 107_CD_plain       0.719685  0.701615      0.000000  0.225656  0.000000
# 279_CD_plain       0.689739  0.213157      0.000000  0.969447  0.000000
# 179_CD_plain       0.734039  0.683655      0.000000  0.369566  0.000000
# 70_CD_deep_ulcer   0.592796  0.889984      0.000000  0.437243  0.000000
# 256_CD_deep_ulcer  0.667492  0.601592      0.000000  0.653043  0.000000
#
#                      RNF125      DARS     DNAI1    MBTPS1
# Patient_ID
# 55_control         0.410887  0.671068  1.000000  0.438527
# 168_CD_plain       0.220356  0.632252  0.000000  0.488578
# 72_control         0.116289  0.000000  0.260194  0.531400
# 120_control        0.342185  0.416527  0.000000  0.545708
# 258_CD_plain       0.498504  0.449224  0.000000  0.689242
# ...                     ...       ...       ...       ...
# 107_CD_plain       0.295914  0.701896  0.000000  0.709542
# 279_CD_plain       0.134090  0.710444  0.000000  0.846294
# 179_CD_plain       0.405814  0.575430  0.000000  0.653918
# 70_CD_deep_ulcer   0.216913  0.514257  0.000000  0.621144
# 256_CD_deep_ulcer  0.409098  0.449809  0.152556  0.599646
#
# [260 rows x 220 columns]

# %%
full_exp_train_proc = full_exp_df.multiply(gene_shap_means_abs, axis='columns').T
full_exp_train_proc
# Out:
# Patient_ID  55_control  168_CD_plain  72_control  120_control  258_CD_plain  \
# AADAC         3.862916      4.130012    4.322933     3.888627      3.853166
# APOA1         0.630725      0.476531    0.596214     0.523328      0.522947
# APOA4         0.026655      0.023066    0.027393     0.024003      0.026193
# APOB          3.394874      2.920992    3.518758     3.558088      3.883551
# APOC3         0.820220      0.626149    0.845934     0.675072      0.691460
# ...                ...           ...         ...          ...           ...
# NXF4          1.764898      0.035718    0.000000     0.000000      0.000000
# RNF125        1.476380      0.791774    0.417845     1.229523      1.791202
# DARS          0.059697      0.056244    0.000000     0.037053      0.039962
# DNAI1         1.764544      0.000000    0.459124     0.000000      0.000000
# MBTPS1        3.728831      4.154416    4.518535     4.640200      5.860681
#
# Patient_ID  254_CD_deep_ulcer  9_CD_plain  111_CD_plain  57_CD_plain  \
# AADAC                3.786731    3.446185      3.252745     4.268357
# APOA1                0.624347    0.384341      0.534961     0.612991
# APOA4                0.027052    0.025412      0.023246     0.030289
# APOB                 3.250917    2.644201      2.552737     3.204385
# APOC3                0.840695    0.656516      0.691809     0.922232
# ...                       ...         ...           ...          ...
# NXF4                 0.000000    0.000000      0.000000     0.000000
# RNF125               0.673844    1.047391      0.636416     0.695740
# DARS                 0.031999    0.052298      0.022871     0.024493
# DNAI1                0.000000    0.000000      0.000000     0.000000
# MBTPS1               1.029330    5.745150      4.855064     5.133881
#
# Patient_ID  216_CD_deep_ulcer  ...  321_CD_plain  12_CD_plain  \
# AADAC                2.157381  ...      3.974562     4.530177
# APOA1                0.241713  ...      0.525239     0.568162
# APOA4                0.020009  ...      0.029660     0.027596
# APOB                 2.153114  ...      3.361505     3.882089
# APOC3                0.444572  ...      0.780490     0.755456
# ...                       ...  ...           ...          ...
# NXF4                 0.000000  ...      0.000000     0.000000
# RNF125               0.598289  ...      1.400870     1.572110
# DARS                 0.055378  ...      0.043048     0.043820
# DNAI1                0.000000  ...      0.000000     0.000000
# MBTPS1               6.384559  ...      5.959549     5.787583
#
# Patient_ID  165_CD_deep_ulcer  286_CD_plain  89_control  107_CD_plain  \
# AADAC                3.470127      5.025448    5.028900      4.046001
# APOA1                0.465652      0.726966    0.652745      0.519569
# APOA4                0.024908      0.035895    0.031686      0.028605
# APOB                 3.185020      4.320632    4.299106      3.190541
# APOC3                0.622414      1.011244    0.823168      0.679694
# ...                       ...           ...         ...           ...
# NXF4                 0.000000      0.000000    0.000000      0.000000
# RNF125               1.177810      1.616703    1.266203      1.063264
# DARS                 0.040483     -0.009721    0.026002      0.062439
# DNAI1                0.186966      0.727349    0.000000      0.000000
# MBTPS1               5.300464      4.851506    5.695926      6.033289
#
# Patient_ID  279_CD_plain  179_CD_plain  70_CD_deep_ulcer  256_CD_deep_ulcer
# AADAC           1.212575      3.981982          2.683989           3.349810
# APOA1           0.159518      0.573673          0.391070           0.472746
# APOA4           0.006771      0.028406          0.021293           0.025262
# APOB            0.526976      3.612358          2.286388           3.563601
# APOC3           0.109105      0.712281          0.557238           0.668957
# ...                  ...           ...               ...                ...
# NXF4            0.000000      0.000000          0.000000           0.000000
# RNF125          0.481806      1.458155          0.779402           1.469954
# DARS            0.063199      0.051189          0.045747           0.040014
# DNAI1           0.000000      0.000000          0.000000           0.269192
# MBTPS1          7.196100      5.560314          5.281639           5.098834
#
# [220 rows x 260 columns]

# %%
# process only for CD deep ulcer
df_cd_deep_proc = df_cd_deep.multiply(gene_shap_means_abs, axis='columns').T
df_cd_deep_proc
# Out:
# Patient_ID  254_CD_deep_ulcer  216_CD_deep_ulcer  263_CD_deep_ulcer  \
# AADAC                3.786731           2.157381           1.483450
# APOA1                0.624347           0.241713           0.169224
# APOA4                0.027052           0.020009           0.006938
# APOB                 3.250917           2.153114           0.739670
# APOC3                0.840695           0.444572           0.186130
# ...                       ...                ...                ...
# NXF4                 0.000000           0.000000           0.000000
# RNF125               0.673844           0.598289           0.496746
# DARS                 0.031999           0.055378           0.046254
# DNAI1                0.000000           0.000000           0.000000
# MBTPS1               1.029330           6.384559           8.503077
#
# Patient_ID  95_CD_deep_ulcer  223_CD_deep_ulcer  99_CD_deep_ulcer  \
# AADAC               1.770244           3.831208          1.234749
# APOA1               0.250467           0.485557          0.126010
# APOA4               0.010960           0.024816          0.005633
# APOB                0.881707           3.403436          0.526055
# APOC3               0.229439           0.621860          0.172742
# ...                      ...                ...               ...
# NXF4                0.000000           0.000000          0.000000
# RNF125              0.613073           1.325986          0.975758
# DARS                0.046962           0.044526          0.047339
# DNAI1               0.000000           0.000000          0.000000
# MBTPS1              6.142758           5.405586          6.391188
#
# Patient_ID  296_CD_deep_ulcer  219_CD_deep_ulcer  138_CD_deep_ulcer  \
# AADAC                2.716991           4.702033           3.461370
# APOA1                0.352684           0.554556           0.513343
# APOA4                0.018953           0.027799           0.029604
# APOB                 2.400138           3.827749           3.135327
# APOC3                0.499216           0.752515           0.775392
# ...                       ...                ...                ...
# NXF4                 0.000000           0.000000           0.000000
# RNF125               1.092693           1.376687           0.755779
# DARS                 0.044297           0.037287           0.022397
# DNAI1                0.000000           0.234207           0.343085
# MBTPS1               6.391919           4.840441           5.222059
#
# Patient_ID  146_CD_deep_ulcer  ...  212_CD_deep_ulcer  230_CD_deep_ulcer  \
# AADAC                3.171340  ...           4.724742           2.818758
# APOA1                0.300759  ...           0.595653           0.188894
# APOA4                0.018692  ...           0.030102           0.012130
# APOB                 2.169758  ...           4.032194           2.151474
# APOC3                0.426479  ...           0.822295           0.257700
# ...                       ...  ...                ...                ...
# NXF4                 1.184553  ...           0.000000           0.000000
# RNF125               0.920201  ...           1.475123           0.685406
# DARS                 0.043176  ...           0.034846           0.046259
# DNAI1                0.000000  ...           0.000000           0.000000
# MBTPS1               5.380015  ...           5.863601           7.399217
#
# Patient_ID  259_CD_deep_ulcer  59_CD_deep_ulcer  98_CD_deep_ulcer  \
# AADAC                1.821408          4.746230          1.555019
# APOA1                0.321585          0.643299          0.241162
# APOA4                0.016411          0.030940          0.012433
# APOB                 1.751051          4.279890          1.046349
# APOC3                0.422661          0.787002          0.365562
# ...                       ...               ...               ...
# NXF4                 0.000000          0.000000          0.000000
# RNF125               0.633382          2.079617          0.259655
# DARS                 0.041372          0.030826          0.098837
# DNAI1                0.000000          0.224512          0.000000
# MBTPS1               6.337423          5.257706          4.931934
#
# Patient_ID  145_CD_deep_ulcer  143_CD_deep_ulcer  165_CD_deep_ulcer  \
# AADAC                3.191487           2.883598           3.470127
# APOA1                0.249872           0.282765           0.465652
# APOA4                0.017175           0.017170           0.024908
# APOB                 2.185002           2.415262           3.185020
# APOC3                0.394521           0.499413           0.622414
# ...                       ...                ...                ...
# NXF4                 0.000000           0.000000           0.000000
# RNF125               0.515498           0.483051           1.177810
# DARS                 0.031036           0.044342           0.040483
# DNAI1                0.081301           0.582404           0.186966
# MBTPS1               5.833911           5.440297           5.300464
#
# Patient_ID  70_CD_deep_ulcer  256_CD_deep_ulcer
# AADAC               2.683989           3.349810
# APOA1               0.391070           0.472746
# APOA4               0.021293           0.025262
# APOB                2.286388           3.563601
# APOC3               0.557238           0.668957
# ...                      ...                ...
# NXF4                0.000000           0.000000
# RNF125              0.779402           1.469954
# DARS                0.045747           0.040014
# DNAI1               0.000000           0.269192
# MBTPS1              5.281639           5.098834
#
# [220 rows x 76 columns]

# %% [markdown]
# ## Consensus KMeans clustering

# %%
# simulate dataset
# 50 samples, 10 features, 3 true clusters
# x, _ = sklearn.datasets.make_blobs(n_samples=50, n_features=10, centers=3, random_state=44)

# apply multiple Consensus K-Means for
# k = 2, ..., 5
# 100 K-Means runs per Consensus K-Means
# draw 80% of the sample for each single K-Means
# draw 50% of the features for each single K-Means
mckm = MultiCKMeans(k=[2, 3, 4, 5], n_rep=100, p_samp=0.8, p_feat=0.5)
mckm.fit(full_exp_train_proc.values)
mckm_res_train = mckm.predict(full_exp_train_proc.values)
# mckm_res_test = mckm.predict(gene_exp_test_proc.values)

# %%
mckm_res_train.plot_metrics(figsize=(12, 7))

# Select a 'good' K
# At k values around 7, BIC, DB, and SIL have a (local) optimum
# ckm_res_k7 = mckm_res_train.ckmeans_results[1]
# fig = ckm_res_k7.plot(figsize=(14,14))

for i, ckm_res in enumerate(mckm_res_train.ckmeans_results):
    fig = ckm_res.plot(figsize=(14,14))
    print("k =", i+2)
    fig.axes[0].set_xticklabels('')
    fig.axes[1].set_yticklabels('')
    fig.axes[0].set_xlabel("Patients")
    fig.axes[1].set_ylabel("Genes")
    plt.show()
# Out:
# k = 2
# k = 3
# k = 4
# k = 5

# %%
# clustering metrics and plots for all k
print('Metrics:')
print(mckm_res_train.metrics)
# Out:
# Metrics:
#    k       sil          bic        db          ch
# 0  2  0.520740  1292.445456  0.923698  215.347031
# 1  3  0.406880  1228.629102  0.934564  186.916079
# 2  4  0.388332  1185.859983  1.097884  172.013200
# 3  5  0.378060  1156.231752  1.050318  159.846802

# %%
# best k:
ckm_res = mckm_res_train.ckmeans_results[3]

cd_deep_clusters = ckm_res.cl
print('Cluster Membership:', cd_deep_clusters)
cd_deep_clusters.shape
# Out:
# Cluster Membership: [1 0 0 4 0 3 0 0 0 3 3 3 4 0 2 3 0 0 0 3 2 3 0 3 4 3 2 0 0 3 2 4 3 3 3 0 0
#  0 3 3 3 2 0 3 0 3 0 0 0 0 3 3 0 3 0 0 2 3 3 3 3 3 0 2 0 1 0 3 2 0 3 3 0 2
#  0 3 2 2 0 1 0 4 4 0 2 0 1 4 3 3 0 4 3 0 0 1 0 3 3 3 2 0 3 3 1 4 1 2 0 3 4
#  3 0 0 4 3 0 3 3 3 0 0 0 0 0 0 2 1 0 4 3 3 3 0 0 0 3 0 1 3 0 0 1 3 0 3 0 2
#  3 0 0 3 2 3 0 4 0 3 0 0 0 3 3 2 0 0 0 3 2 2 3 0 0 3 0 0 0 0 2 0 0 0 0 0 0
#  4 3 2 0 3 3 3 4 0 2 0 0 0 0 0 3 0 1 0 1 4 3 0 0 0 1 3 0 0 3 0 3 0 0 1]
# (220,)

# %% [markdown]
# ## Only CD deep ulcer patients (?)

# %%
mckm = MultiCKMeans(k=[2, 3, 4, 5], n_rep=100, p_samp=0.8, p_feat=0.5)
mckm.fit(df_cd_deep_proc.values)
mckm_res_train = mckm.predict(df_cd_deep_proc.values)
# mckm_res_test = mckm.predict(gene_exp_test_proc.values)

# %%
df_cd_deep_proc
# Out:
# Patient_ID  254_CD_deep_ulcer  216_CD_deep_ulcer  263_CD_deep_ulcer  \
# AADAC                3.786731           2.157381           1.483450
# APOA1                0.624347           0.241713           0.169224
# APOA4                0.027052           0.020009           0.006938
# APOB                 3.250917           2.153114           0.739670
# APOC3                0.840695           0.444572           0.186130
# ...                       ...                ...                ...
# NXF4                 0.000000           0.000000           0.000000
# RNF125               0.673844           0.598289           0.496746
# DARS                 0.031999           0.055378           0.046254
# DNAI1                0.000000           0.000000           0.000000
# MBTPS1               1.029330           6.384559           8.503077
#
# Patient_ID  95_CD_deep_ulcer  223_CD_deep_ulcer  99_CD_deep_ulcer  \
# AADAC               1.770244           3.831208          1.234749
# APOA1               0.250467           0.485557          0.126010
# APOA4               0.010960           0.024816          0.005633
# APOB                0.881707           3.403436          0.526055
# APOC3               0.229439           0.621860          0.172742
# ...                      ...                ...               ...
# NXF4                0.000000           0.000000          0.000000
# RNF125              0.613073           1.325986          0.975758
# DARS                0.046962           0.044526          0.047339
# DNAI1               0.000000           0.000000          0.000000
# MBTPS1              6.142758           5.405586          6.391188
#
# Patient_ID  296_CD_deep_ulcer  219_CD_deep_ulcer  138_CD_deep_ulcer  \
# AADAC                2.716991           4.702033           3.461370
# APOA1                0.352684           0.554556           0.513343
# APOA4                0.018953           0.027799           0.029604
# APOB                 2.400138           3.827749           3.135327
# APOC3                0.499216           0.752515           0.775392
# ...                       ...                ...                ...
# NXF4                 0.000000           0.000000           0.000000
# RNF125               1.092693           1.376687           0.755779
# DARS                 0.044297           0.037287           0.022397
# DNAI1                0.000000           0.234207           0.343085
# MBTPS1               6.391919           4.840441           5.222059
#
# Patient_ID  146_CD_deep_ulcer  ...  212_CD_deep_ulcer  230_CD_deep_ulcer  \
# AADAC                3.171340  ...           4.724742           2.818758
# APOA1                0.300759  ...           0.595653           0.188894
# APOA4                0.018692  ...           0.030102           0.012130
# APOB                 2.169758  ...           4.032194           2.151474
# APOC3                0.426479  ...           0.822295           0.257700
# ...                       ...  ...                ...                ...
# NXF4                 1.184553  ...           0.000000           0.000000
# RNF125               0.920201  ...           1.475123           0.685406
# DARS                 0.043176  ...           0.034846           0.046259
# DNAI1                0.000000  ...           0.000000           0.000000
# MBTPS1               5.380015  ...           5.863601           7.399217
#
# Patient_ID  259_CD_deep_ulcer  59_CD_deep_ulcer  98_CD_deep_ulcer  \
# AADAC                1.821408          4.746230          1.555019
# APOA1                0.321585          0.643299          0.241162
# APOA4                0.016411          0.030940          0.012433
# APOB                 1.751051          4.279890          1.046349
# APOC3                0.422661          0.787002          0.365562
# ...                       ...               ...               ...
# NXF4                 0.000000          0.000000          0.000000
# RNF125               0.633382          2.079617          0.259655
# DARS                 0.041372          0.030826          0.098837
# DNAI1                0.000000          0.224512          0.000000
# MBTPS1               6.337423          5.257706          4.931934
#
# Patient_ID  145_CD_deep_ulcer  143_CD_deep_ulcer  165_CD_deep_ulcer  \
# AADAC                3.191487           2.883598           3.470127
# APOA1                0.249872           0.282765           0.465652
# APOA4                0.017175           0.017170           0.024908
# APOB                 2.185002           2.415262           3.185020
# APOC3                0.394521           0.499413           0.622414
# ...                       ...                ...                ...
# NXF4                 0.000000           0.000000           0.000000
# RNF125               0.515498           0.483051           1.177810
# DARS                 0.031036           0.044342           0.040483
# DNAI1                0.081301           0.582404           0.186966
# MBTPS1               5.833911           5.440297           5.300464
#
# Patient_ID  70_CD_deep_ulcer  256_CD_deep_ulcer
# AADAC               2.683989           3.349810
# APOA1               0.391070           0.472746
# APOA4               0.021293           0.025262
# APOB                2.286388           3.563601
# APOC3               0.557238           0.668957
# ...                      ...                ...
# NXF4                0.000000           0.000000
# RNF125              0.779402           1.469954
# DARS                0.045747           0.040014
# DNAI1               0.000000           0.269192
# MBTPS1              5.281639           5.098834
#
# [220 rows x 76 columns]

# %%
mckm_res_train.plot_metrics(figsize=(12, 7))

for i, ckm_res in enumerate(mckm_res_train.ckmeans_results):
    
    fig = ckm_res.plot(figsize=(14,14))
    print("k =", i+2)
    fig.axes[0].set_xticklabels('')
    fig.axes[1].set_yticklabels('')
    fig.axes[0].set_xlabel("Patients")
    fig.axes[1].set_ylabel("Genes")
    plt.show()
# Out:
# k = 2
# k = 3
# k = 4
# k = 5

# %% [markdown]
# ## Aggregate bar plot, showing potential gene modules alongside SHAP contributions for CD deep ulcer patients

# %%
shap_df = df_train_cd_deep_shap.describe().T
shap_df["cluster_num"] = cd_deep_clusters
shap_df["gene_symbol"] = shap_df.index
shap_df
# Out:
#         count      mean        std         min        25%       50%  \
# AADAC    24.0 -5.496363  11.652575  -34.890732 -11.931632 -1.562356
# APOA1    24.0 -0.789341  16.642071  -47.298582  -2.419380  0.000000
# APOA4    24.0 -0.037038  16.198998  -24.597463  -9.649359 -0.495575
# APOB     24.0  4.653398  29.010648 -101.019448   0.000000  4.242113
# APOC3    24.0 -1.031784  13.705945  -35.051066  -5.279232  0.050643
# ...       ...       ...        ...         ...        ...       ...
# NXF4     24.0  1.764898   8.491458   -7.673958  -3.928331  0.551885
# RNF125   24.0  3.593158  21.356245  -49.988338  -3.129121  0.000000
# DARS     24.0  0.088958  16.491311  -42.729326  -4.007470  0.000000
# DNAI1    24.0  1.764544  17.661747  -35.833474  -5.200349 -0.074214
# MBTPS1   24.0  8.503077  22.801953  -25.912554  -0.409944  0.715804
#
#               75%        max  cluster_num gene_symbol
# AADAC    2.445564  13.083386            1       AADAC
# APOA1    4.666901  35.764123            0       APOA1
# APOA4    3.916130  57.741192            0       APOA4
# APOB     9.345444  85.675325            4        APOB
# APOC3    2.537448  42.587423            0       APOC3
# ...           ...        ...          ...         ...
# NXF4     3.311928  30.051868            0        NXF4
# RNF125   7.496647  72.389340            3      RNF125
# DARS     7.237860  42.873870            0        DARS
# DNAI1    4.381183  58.721092            0       DNAI1
# MBTPS1  15.601786  96.835082            1      MBTPS1
#
# [220 rows x 10 columns]

# %%
mean_df = shap_df[['mean','cluster_num','gene_symbol']]
mean_df
# Out:
#             mean  cluster_num gene_symbol
# AADAC  -5.496363            1       AADAC
# APOA1  -0.789341            0       APOA1
# APOA4  -0.037038            0       APOA4
# APOB    4.653398            4        APOB
# APOC3  -1.031784            0       APOC3
# ...          ...          ...         ...
# NXF4    1.764898            0        NXF4
# RNF125  3.593158            3      RNF125
# DARS    0.088958            0        DARS
# DNAI1   1.764544            0       DNAI1
# MBTPS1  8.503077            1      MBTPS1
#
# [220 rows x 3 columns]

# %%
def group_fn(data):
    d = {}
    mean_vals = data['mean']
    symbols = list(data['gene_symbol'])
#     print(mean_vals)
#     print(symbols)
    mean_dict = {symbols[i]: abs(mean_vals[i]) for i in range(len(symbols))}
#     print(mean_dict)
    gene_dict = dict(sorted(mean_dict.items(), key=lambda x : x[1], reverse=True))
    gene_list = list(gene_dict.keys())
#     print(gene_list)
    d['sum'] = np.sum(data['mean'])
    d['gene_count'] = data['mean'].count()
    d['grouped_genes'] = gene_list
    return pd.Series(d)

def group_labels(x):
    if len(x) > 4:
        gene_list = x[:4]
    else:
        gene_list = x
    return ", ".join(gene_list)

def add_other(num, curr_label, max_display=4):
#     print(type(num))
#     print(type(curr_label))
    if num > 1:
        if num > 2: 
            other = " others" 
            num_displayed = min(num, max_display)
        else:
            num_displayed = 2
            other = " other"
        rem = num - num_displayed
        if rem == 0:
            return curr_label
        return curr_label + " + " + str(rem) + other
    else:
        return curr_label

# %%
agg_df = mean_df.groupby(['cluster_num'])
agg_df = agg_df.apply(group_fn)
agg_df
# Out:
#                    sum  gene_count  \
# cluster_num
# 0           -17.207492          98
# 1            59.320061          14
# 2           -17.456783          23
# 3             3.614565          69
# 4           -26.274254          16
#
#                                                  grouped_genes
# cluster_num
# 0            [TBPL2, FABP12, CSTT, S100A12, PROK2, TPRKB, M...
# 1            [PNLIPRP2, TLR4, SLC5A11, MBTPS1, NAT8B, HDLBP...
# 2            [CXCL11, CXCL5, MUC5B, CSF3, REG1P, SLC11A1, C...
# 3            [RPS4X, IL23R, IL1RN, TLR6, HCAR2, SAMD8, CNR1...
# 4            [CRIP1, TCF7L2, FOXD1, GSTA1, SLC22A5, APOB, M...

# %%
agg_df["cluster_labels"] = agg_df["grouped_genes"].apply(group_labels)
# agg_df["cluster_labels"] = agg_df["count"].apply(add_other)

agg_df['cluster_labels'] = agg_df.apply(lambda x: add_other(x["gene_count"], x["cluster_labels"]), axis=1)
agg_df
# Out:
#                    sum  gene_count  \
# cluster_num
# 0           -17.207492          98
# 1            59.320061          14
# 2           -17.456783          23
# 3             3.614565          69
# 4           -26.274254          16
#
#                                                  grouped_genes  \
# cluster_num
# 0            [TBPL2, FABP12, CSTT, S100A12, PROK2, TPRKB, M...
# 1            [PNLIPRP2, TLR4, SLC5A11, MBTPS1, NAT8B, HDLBP...
# 2            [CXCL11, CXCL5, MUC5B, CSF3, REG1P, SLC11A1, C...
# 3            [RPS4X, IL23R, IL1RN, TLR6, HCAR2, SAMD8, CNR1...
# 4            [CRIP1, TCF7L2, FOXD1, GSTA1, SLC22A5, APOB, M...
#
#                                           cluster_labels
# cluster_num
# 0               TBPL2, FABP12, CSTT, S100A12 + 94 others
# 1            PNLIPRP2, TLR4, SLC5A11, MBTPS1 + 10 others
# 2                 CXCL11, CXCL5, MUC5B, CSF3 + 19 others
# 3                  RPS4X, IL23R, IL1RN, TLR6 + 65 others
# 4                CRIP1, TCF7L2, FOXD1, GSTA1 + 12 others

# %%
plt.rcParams.update({'font.size': 14})
plt.rcParams["figure.figsize"] = (6,6)
agg_df.plot.barh(x="cluster_labels", y="sum", legend=None, zorder=2, color=(agg_df['sum'] > 0).map({True: 'g',False: 'r'}))

plt.title('SHAP contributions by cluster')
plt.ylabel('Gene sets')
plt.xlabel('SHAP value (sum)')
plt.xlim((-70, 70))
for i, v in enumerate(agg_df["sum"]):
    v = np.round(v, 3)
    vt = "+{:.3f}".format(v) if v >= 0 else "{:.3f}".format(v)
    offset = -.13 if v < 0 else .02
    colour = 'darkred' if v < 0 else 'darkgreen'
#     plt.text(v + offset, i + .08, vt, color=colour, zorder=3)
#     plt.axhline(i,linewidth=.07, color='k', zorder=1, linestyle='--')
    

fig.set_dpi(100)
plt.axvline(0,linewidth=.2, color='k')
size = fig.get_size_inches()[1]
plt.axhline(size + .045*size,linewidth=.9, color='k')

plt.tick_params(axis=u'both', which=u'both',length=0)
plt.gca().invert_yaxis()
plt.box(on=False)

plt.show()

# %%
agg_df["grouped_genes"]
# Out:
# cluster_num
# 0    [TBPL2, FABP12, CSTT, S100A12, PROK2, TPRKB, M...
# 1    [PNLIPRP2, TLR4, SLC5A11, MBTPS1, NAT8B, HDLBP...
# 2    [CXCL11, CXCL5, MUC5B, CSF3, REG1P, SLC11A1, C...
# 3    [RPS4X, IL23R, IL1RN, TLR6, HCAR2, SAMD8, CNR1...
# 4    [CRIP1, TCF7L2, FOXD1, GSTA1, SLC22A5, APOB, M...
# Name: grouped_genes, dtype: object

# %%
for li in agg_df["grouped_genes"]:
    print(len(li),"genes:")
    for item in li:
        print(item)
    print("----------------------")
# Out:
# 98 genes:
# TBPL2
# FABP12
# CSTT
# S100A12
# PROK2
# TPRKB
# MIF
# HIST1H4C
# TTTY1B
# CRP
# ADRA1A
# SELE
# TREM1
# IRGM
# ZNF365
# FPR1
# LCT
# CLDN8
# C6
# NALCN
# NXF4
# DNAI1
# EGFL6
# IL10
# HLA_DRB5
# HMGCS2
# ADH1B
# CHI3L1
# SLC10A2
# FADS6
# NEUROD6
# FCN1
# LOC255512
# CLEC4D
# JOSD2
# FCRL4
# LOC392364
# LRRC42
# HOMER3
# FABP6
# FCRL3
# SLC5A12
# CLEC5A
# MEP1B
# CRYAB
# NOD2
# RGS13
# HLA_DRB1
# ASB15
# SPTY2D1
# BPIFB1
# APOC3
# SLC34A3
# PGC
# PTPN2
# PWWP2A
# SDAD1P1
# APOA1
# IL10RB
# LOC100507531
# OTOP3
# TCF4
# SHBG
# TM4SF4
# CEBPB
# HCAR3
# C6orf99
# IL12B
# SLC6A14
# JAK2
# CXCR1
# GSTA5
# CEACAM7
# DLG5
# NMNAT3
# UTF1
# TPMT
# TLR1
# TLR2
# SERPINA9
# MUC2
# FPR2
# SLC23A3
# SLC28A2
# CYP3A4
# AGXT2
# PTPN22
# SAA2
# LRRK2
# FCGR1A
# ITIH3
# OR9A4
# DARS
# DHDH
# SLC13A1
# FAM151A
# APOA4
# OR4F15
# ----------------------
# 14 genes:
# PNLIPRP2
# TLR4
# SLC5A11
# MBTPS1
# NAT8B
# HDLBP
# CUBN
# CDHR1
# SLC22A4
# CYP4F2
# REPS1
# AADAC
# ZNF879
# SFRP5
# ----------------------
# 23 genes:
# CXCL11
# CXCL5
# MUC5B
# CSF3
# REG1P
# SLC11A1
# CD300E
# CXCL9
# C19orf59
# SELP
# IL8
# FOLH1
# FCGR3A
# DUOX2
# OSM
# C10orf2
# TNFAIP6
# FCGR1C
# GLT1D1
# FCN3
# CXCL3
# P2RY14
# SAA1
# ----------------------
# 69 genes:
# RPS4X
# IL23R
# IL1RN
# TLR6
# HCAR2
# SAMD8
# CNR1
# CDIPT
# TNFAIP3
# TNFAIP2
# CCDC149
# LOC100506115
# MUC1
# MMP10
# TCN1
# LTA
# CXCR2
# RNF125
# FAM83A
# FCGR3B
# STAT3
# S100A9
# OTOP2
# TNF
# DUOXA2
# MDH2
# FCGR1B
# LAMC3
# HSD11B1
# FLJ35424
# TYK2
# KCNJ15
# AQP9
# IL10RA
# HLA_B
# MMP3
# LRAT
# MMP7
# S100A8
# G6PC
# DAPK2
# SUSD2
# LYPD1
# FOLH1B
# IL1B
# ALDH1A2
# CYP3A7
# XPNPEP2
# REG1A
# FRMD1
# CYP4F11
# MMP1
# CXCL6
# STAT1
# FMO1
# C9orf71
# FHIT
# NAT8
# LCN2
# ABCC2
# PIAS4
# GSTA2
# PTPN21
# CNTFR
# FBXO11
# ATG16L1
# GUCA2B
# CPO
# MS4A10
# ----------------------
# 16 genes:
# CRIP1
# TCF7L2
# FOXD1
# GSTA1
# SLC22A5
# APOB
# MIR1247
# FDCSP
# LINC00342
# AKAP1
# SLC6A4
# SOAT2
# UGT1A6
# MGAM
# SLC5A4
# SLC28A1
# ----------------------

# %% [markdown]
# ## Biological significance of identified gene modules
